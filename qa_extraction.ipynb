# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install transformers
# !pip install pyvi
# !pip install cdlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.30.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.3.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: cdlib in /usr/local/lib/python3.10/dist-packages (0.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from cdlib) (1.22.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from cdlib) (3.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from cdlib) (1.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from cdlib) (4.65.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from cdlib) (3.1)
# Requirement already satisfied: demon in /usr/local/lib/python3.10/dist-packages (from cdlib) (2.0.6)
# Requirement already satisfied: python-louvain>=0.16 in /usr/local/lib/python3.10/dist-packages (from cdlib) (0.16)
# Requirement already satisfied: nf1 in /usr/local/lib/python3.10/dist-packages (from cdlib) (0.0.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from cdlib) (1.10.1)
# Requirement already satisfied: pulp in /usr/local/lib/python3.10/dist-packages (from cdlib) (2.7.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from cdlib) (0.12.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from cdlib) (1.5.3)
# Requirement already satisfied: eva-lcd in /usr/local/lib/python3.10/dist-packages (from cdlib) (0.1.1)
# Requirement already satisfied: bimlpa in /usr/local/lib/python3.10/dist-packages (from cdlib) (0.1.2)
# Requirement already satisfied: markov-clustering in /usr/local/lib/python3.10/dist-packages (from cdlib) (0.0.6.dev0)
# Requirement already satisfied: python-igraph>=0.10 in /usr/local/lib/python3.10/dist-packages (from cdlib) (0.10.4)
# Requirement already satisfied: angelcommunity in /usr/local/lib/python3.10/dist-packages (from cdlib) (2.0.0)
# Requirement already satisfied: pooch in /usr/local/lib/python3.10/dist-packages (from cdlib) (1.6.0)
# Requirement already satisfied: dynetx in /usr/local/lib/python3.10/dist-packages (from cdlib) (0.3.2)
# Requirement already satisfied: thresholdclustering in /usr/local/lib/python3.10/dist-packages (from cdlib) (1.1)
# Requirement already satisfied: python-Levenshtein in /usr/local/lib/python3.10/dist-packages (from cdlib) (0.21.1)
# Requirement already satisfied: igraph==0.10.4 in /usr/local/lib/python3.10/dist-packages (from python-igraph>=0.10->cdlib) (0.10.4)
# Requirement already satisfied: texttable>=1.6.2 in /usr/local/lib/python3.10/dist-packages (from igraph==0.10.4->python-igraph>=0.10->cdlib) (1.6.7)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from angelcommunity->cdlib) (0.18.3)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from dynetx->cdlib) (4.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cdlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cdlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cdlib) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cdlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cdlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cdlib) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cdlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cdlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->cdlib) (2022.7.1)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from pooch->cdlib) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch->cdlib) (2.27.1)
# Requirement already satisfied: Levenshtein==0.21.1 in /usr/local/lib/python3.10/dist-packages (from python-Levenshtein->cdlib) (0.21.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from Levenshtein==0.21.1->python-Levenshtein->cdlib) (3.1.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->cdlib) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->cdlib) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->cdlib) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch->cdlib) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch->cdlib) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch->cdlib) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch->cdlib) (3.4)

# %%
import json
from glob import glob
import re
from nltk import word_tokenize as lib_tokenizer
import string


def preprocess(x, max_length=-1, remove_puncts=False):
    x = nltk_tokenize(x)
    x = x.replace("\n", " ")
    if remove_puncts:
        x = "".join([i for i in x if i not in string.punctuation])
    if max_length > 0:
        x = " ".join(x.split()[:max_length])
    return x


def nltk_tokenize(x):
    return " ".join(word_tokenize(strip_context(x))).strip()


def post_process_answer(x, entity_dict):
    if type(x) is not str:
        return x
    try:
        x = strip_answer_string(x)
    except:
        return "NaN"
    x = "".join([c for c in x if c not in string.punctuation])
    x = " ".join(x.split())
    y = x.lower()
    if len(y) > 1 and y.split()[0].isnumeric() and ("tháng" not in x):
        return y.split()[0]
    if not (x.isnumeric() or "ngày" in x or "tháng" in x or "năm" in x):
        if len(x.split()) <= 2:
            return entity_dict.get(x.lower(), x)
        else:
            return x
    else:
        return y


dict_map = dict({})


def word_tokenize(text):
    global dict_map
    words = text.split()
    words_norm = []
    for w in words:
        if dict_map.get(w, None) is None:
            dict_map[w] = ' '.join(lib_tokenizer(w)).replace('``', '"').replace("''", '"')
        words_norm.append(dict_map[w])
    return words_norm


def strip_answer_string(text):
    text = text.strip()
    while text[-1] in '.,/><;:\'"[]{}+=-_)(*&^!~`':
        if text[0] != '(' and text[-1] == ')' and '(' in text:
            break
        if text[-1] == '"' and text[0] != '"' and text.count('"') > 1:
            break
        text = text[:-1].strip()
    while text[0] in '.,/><;:\'"[]{}+=-_)(*&^!~`':
        if text[0] == '"' and text[-1] != '"' and text.count('"') > 1:
            break
        text = text[1:].strip()
    text = text.strip()
    return text


def strip_context(text):
    text = text.replace('\n', ' ')
    text = re.sub(r'\s+', ' ', text)
    text = text.strip()
    return text


def check_number(x):
    x = str(x).lower()
    return (x.isnumeric() or "ngày" in x or "tháng" in x or "năm" in x)

# %%
import networkx as nx
import numpy as np
from cdlib import algorithms


# these functions are heavily influenced by the HF squad_metrics.py script
def normalize_text(s):
    """Removing articles and punctuation, and standardizing whitespace are all typical text processing steps."""
    import string, re

    def remove_articles(text):
        regex = re.compile(r"\b(a|an|the)\b", re.UNICODE)
        return re.sub(regex, " ", text)

    def white_space_fix(text):
        return " ".join(text.split())

    def remove_punc(text):
        exclude = set(string.punctuation)
        return "".join(ch for ch in text if ch not in exclude)

    def lower(text):
        return text.lower()

    return white_space_fix(remove_articles(remove_punc(lower(s))))


def compute_exact_match(prediction, truth):
    return int(normalize_text(prediction) == normalize_text(truth))


def compute_f1(prediction, truth):
    pred_tokens = normalize_text(prediction).split()
    truth_tokens = normalize_text(truth).split()

    # if either the prediction or the truth is no-answer then f1 = 1 if they agree, 0 otherwise
    if len(pred_tokens) == 0 or len(truth_tokens) == 0:
        return int(pred_tokens == truth_tokens)

    common_tokens = set(pred_tokens) & set(truth_tokens)

    # if there are no common tokens then f1 = 0
    if len(common_tokens) == 0:
        return 0

    prec = len(common_tokens) / len(pred_tokens)
    rec = len(common_tokens) / len(truth_tokens)

    return 2 * (prec * rec) / (prec + rec)


def is_date_or_num(answer):
    answer = answer.lower().split()
    for w in answer:
        w = w.strip()
        if w.isnumeric() or w in ["ngày", "tháng", "năm"]:
            return True
    return False


def find_best_cluster(answers, best_answer, thr=0.79):
    if len(answers) == 0:  # or best_answer not in answers:
        return best_answer
    elif len(answers) == 1:
        return answers[0]
    dists = np.zeros((len(answers), len(answers)))
    for i in range(len(answers) - 1):
        for j in range(i + 1, len(answers)):
            a1 = answers[i].lower().strip()
            a2 = answers[j].lower().strip()
            if is_date_or_num(a1) or is_date_or_num(a2):
                # print(a1, a2)
                if a1 == a2 or ("tháng" in a1 and a1 in a2) or ("tháng" in a2 and a2 in a1):
                    dists[i, j] = 1
                    dists[j, i] = 1
                # continue
            elif a1 == a2 or (a1 in a2) or (a2 in a1) or compute_f1(a1.lower(), a2.lower()) >= thr:
                dists[i, j] = 1
                dists[j, i] = 1
    # print(dists)
    try:
        thr = 1
        dups = np.where(dists >= thr)
        dup_strs = []
        edges = []
        for i, j in zip(dups[0], dups[1]):
            if i != j:
                edges.append((i, j))
        G = nx.Graph()
        for i, answer in enumerate(answers):
            G.add_node(i, content=answer)
        G.add_edges_from(edges)
        partition = algorithms.louvain(G)
        max_len_comm = np.max([len(x) for x in partition.communities])
        best_comms = []
        for comm in partition.communities:
            # print([answers[i] for i in comm])
            if len(comm) == max_len_comm:
                best_comms.append([answers[i] for i in comm])
        # if len(best_comms) > 1:
        #     return best_answer
        for comm in best_comms:
            if best_answer in comm:
                return best_answer
        mid = len(best_comms[0]) // 2
        # print(mid, sorted(best_comms[0], key = len))
        return sorted(best_comms[0], key=len)[mid]
    except Exception as e:
        print(e, "Disconnected graph")
        return best_answer
# Out:
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'wurlitzer', 'infomap', 'bayanpy', 'graph_tool', 'leidenalg'}
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'ASLPAw', 'pyclustering'}
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'leidenalg', 'wurlitzer', 'infomap'}

# %%
import torch
import torch.nn as nn
import pandas as pd
import nltk
nltk.download('punkt')
# from pyvi import ViTokenizer
import numpy as np

from transformers import AutoModelForQuestionAnswering, pipeline, AutoTokenizer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
DRIVE_PATH = '/content/drive/MyDrive/question_answering_data/'
MRC_MODEL = 'nguyenvulebinh/vi-mrc-base'
MRC_TOKENIZER = 'nguyenvulebinh/vi-mrc-large'
AUTH_TOKEN = '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'
WEIGHT_QA = 'qa_robust_cuong.bin'

# %% [markdown]
# #Model

# %%
rank_wiki = pd.read_csv(DRIVE_PATH + 'rank_qa.csv')
rank_wiki = rank_wiki.drop('Unnamed: 0', axis=1)
rank_wiki
# Out:
#                                                 title  \
# 0   100 ngày đầu nhiệm kỳ tổng thống của Donald Trump
# 1                                              Hoa Kỳ
# 2                                Nội các Donald Trump
# 3                                        Donald Trump
# 4                                        Donald Trump
# ..                                                ...
# 95                                     Trần Đại Quang
# 96  Truyền thông xã hội trong bầu cử tổng thống Ho...
# 97                       Các bí danh của Donald Trump
# 98                         D.C. and Maryland v. Trump
# 99                                       Giải Tin giả
#
#                                                  text  \
# 0   100 ngày đầu nhiệm kỳ tổng thống của Donald Tr...
# 1   Mặc cho các cáo buộc và hàng loạt các cuộc biể...
# 2   Nội các Donald Trump  () là Nội các Tổng thống...
# 3   Donald Trump\n\nDonald John Trump (sinh ngày 1...
# 4   chiến thắng để trở thành ứng cử viên đại diện ...
# ..                                                ...
# 95  hai nước viết tiếp những trang sử mới. Chia sẻ...
# 96  Truyền thông xã hội trong bầu cử tổng thống Ho...
# 97  Các bí danh của Donald Trump\n\nDoanh nhân, ch...
# 98  D.C. and Maryland v. Trump  (tạm dịch Washingt...
# 99  Giải Tin giả  (Anh: Fake News Awards) được Tổn...
#
#                                               context  \
# 0   100 ngày đầu nhiệm_kỳ tổng_thống của donald_tr...
# 1   mặc cho các cáo_buộc và hàng_loạt các cuộc biể...
# 2   nội_các donald trump là nội_các tổng_thống don...
# 3   donald_trump donald john trump sinh ngày 14 th...
# 4   chiến_thắng để trở_thành ứng_cử_viên đại_diện ...
# ..                                                ...
# 95  hai nước viết tiếp những trang sử mới chia_sẻ ...
# 96  truyền_thông xã_hội trong bầu_cử tổng_thống ho...
# 97  các bí_danh của donald_trump doanh_nhân chính_...
# 98  dc and maryland v trump tạm dịch washington dc...
# 99  giải tin giả anh fake news awards được tổng_th...
#
#                                              question  bm25_score  bert_score
# 0   donald trump làm tổng_thống hoa kỳ từ thơi điể...    0.252472    0.985611
# 1   donald trump làm tổng_thống hoa kỳ từ thơi điể...    0.231102    0.978186
# 2   donald trump làm tổng_thống hoa kỳ từ thơi điể...    0.221632    0.995207
# 3   donald trump làm tổng_thống hoa kỳ từ thơi điể...    0.220300    0.986720
# 4   donald trump làm tổng_thống hoa kỳ từ thơi điể...    0.213287    0.949088
# ..                                                ...         ...         ...
# 95  donald trump làm tổng_thống hoa kỳ từ thơi điể...    0.269060    0.022392
# 96  donald trump làm tổng_thống hoa kỳ từ thơi điể...    0.195428    0.030811
# 97  donald trump làm tổng_thống hoa kỳ từ thơi điể...    0.176048    0.034166
# 98  donald trump làm tổng_thống hoa kỳ từ thơi điể...    0.221913    0.026267
# 99  donald trump làm tổng_thống hoa kỳ từ thơi điể...    0.230100    0.025250
#
# [100 rows x 6 columns]

# %%
entity_dict = json.load(open(DRIVE_PATH + "processed/entities.json"))
new_dict = dict()
for key, val in entity_dict.items():
    val = val.replace("wiki/", "").replace("_", " ")
    entity_dict[key] = val
    key = preprocess(key)
    new_dict[key.lower()] = val
entity_dict.update(new_dict)
entity_dict
# Out:
# {'Costa Rica, Iceland, Panama, Micronesia, Quần đảo Marshall, và Vatican...': 'Danh sách quốc gia không có lực lượng vũ trang',
#  'núi Elbrus': 'Elbrus',
#  'Alexandria': 'Alexandria',
#  'Lê Chân': 'Lê Chân',
#  'Ý': 'Ý',
#  'Phan Thiết': 'Phan Thiết',
#  'xã Nhơn Lý': 'Nhơn Lý',
#  'Google': 'Google',
#  'tỉnh Gia Lai': 'Gia Lai',
#  'tỉnh Quảng Nam': 'Quảng Nam',
#  'vua Khải Định': 'Khải Định',
#  'theo thể lục bát': 'Lục bát (thể thơ)',
#  'Trần Duy Hưng': 'Trần Duy Hưng',
#  'Suối Tranh': 'Suối Tranh',
#  'chùa làng Vũ Lam huyện Gia Khánh (Ninh Bình)': 'Hành cung Vũ Lâm',
#  'Nguyễn Phú Trọng': 'Nguyễn Phú Trọng',
#  'Pháp': 'Pháp',
#  'tỉnh An Giang': 'An Giang',
#  'tỉnh Bắc Kạn': 'Bắc Kạn',
#  'Nguyễn Văn Tý': 'Nguyễn Văn Tý',
#  'Huế': 'Huế',
#  'tại Hamilton Crescent thuộc Glasgow giữa Scotland và Anh': 'Glasgow',
#  'Hà Lan': 'Hà Lan',
#  'Cộng hoà Nam Phi': 'Cộng hòa Nam Phi',
#  'vị hoàng tử Lang Liêu': 'Lang Liêu',
#  'Nam Mỹ': 'Nam Mỹ',
#  'J. K. Rowling': 'J. K. Rowling',
#  'sa mạc Ả Rập': 'Hoang mạc Ả Rập',
#  'nhà văn J. R. R. Tolkien': 'J. R. R. Tolkien',
#  'miền Nam Việt Nam': 'Miền Nam (Việt Nam)',
#  'Bình Nhưỡng hay Pyongyang': 'Bình Nhưỡng',
#  'Bratislava': 'Bratislava',
#  'Khương Công Phụ': 'Khương Công Phụ',
#  'Nguyễn An': 'Nguyễn An',
#  'Đại Tây Dương': 'Đại Tây Dương',
#  'Gustave Eiffel': 'Gustave Eiffel',
#  'tỉnh Bắc Ninh': 'Bắc Ninh',
#  'Văn Cao': 'Văn Cao',
#  'campuchia': 'Campuchia',
#  'SR-71 " Blackbird "': 'Lockheed SR-71 Blackbird',
#  'hang Sơn Đoòng': 'Hang Sơn Đoòng',
#  'trong Bến cảng New York': 'Cảng New York và New Jersey',
#  'Địa Trung Hải': 'Địa Trung Hải',
#  'núi Cấm': 'Núi Cấm',
#  'tỉnh Bình Phước': 'Bình Phước',
#  'người Mỹ': 'Người Mỹ',
#  'Đà Nẵng': 'Đà Nẵng',
#  'Dương Đông': 'Dương Đông (phường)',
#  'Ba Tư': 'Iran',
#  'hồ Kim Ngưu': 'Hồ Tây',
#  'Nguyễn Hiền': 'Nguyễn Hiền',
#  'vua Lý Thần Tông': 'Lý Thần Tông',
#  'vua Minh Mạng': 'Minh Mạng',
#  'tỉnh Đắk Nông': 'Đắk Nông',
#  'Bồ Đào Nha': 'Bồ Đào Nha',
#  'George Washington': 'George Washington',
#  'Nguyễn Ngọc Hai': 'Nguyễn Ngọc Hai',
#  'nghĩa quân Lam Sơn': 'Khởi nghĩa Lam Sơn',
#  'Thành phố Hồ Chí Minh': 'Thành phố Hồ Chí Minh',
#  'Cuối thời Trần': 'Nhà Trần',
#  'Ngô Đình Diệm': 'Ngô Đình Diệm',
#  'biển Adriatic': 'Biển Adriatic',
#  'nhà Trần': 'Nhà Trần',
#  'sông Đà Rằng': 'Sông Ba',
#  'Hoa Lư': 'Hoa Lư',
#  '44S-sv-Sh': 'T-14 Armata',
#  'Trần Quốc Tuấn': 'Trần Hưng Đạo',
#  'Hoàng tế Philip': 'Philip, Vương tế Anh',
#  'Võ Nguyên Giáp': 'Võ Nguyên Giáp',
#  'vua Thiệu Trị': 'Thiệu Trị',
#  'Kuala Lumpur': 'Kuala Lumpur',
#  'tỉnh Quảng Ninh': 'Quảng Ninh',
#  'Phan Huy Chú': 'Phan Huy Chú',
#  'Naypyidaw': 'Naypyidaw',
#  'Phần Lan': 'Bắc Âu',
#  'Alasane Ouattara': 'Alassane Ouattara',
#  'Brasil': 'Brasil',
#  'cà phê chồn Buôn Ma Thuột .': 'Cà phê chồn Đắk Lắk',
#  'Ban Thường vụ Bộ Chính trị Đảng Cộng sản Trung Quốc': 'Ban Thường vụ Bộ Chính trị Đảng Cộng sản Trung Quốc',
#  'Châu Phi': 'Châu Phi',
#  'Nguyễn Dữ': 'Nguyễn Dữ',
#  'Thọ Xuân': 'Thọ Xuân',
#  'Thành phố San Marino': 'Thành phố San Marino',
#  'Neil Armstrong': 'Neil Armstrong',
#  'Tòa nhà Burj Khalifa': 'Burj Khalifa',
#  'Nguyễn Du': 'Nguyễn Du',
#  'Sông Volga': 'Sông Volga',
#  'Addis Ababa': 'Addis Ababa',
#  'Văn Lang': 'Văn Lang',
#  'huyện Gia Lâm': 'Gia Lâm',
#  'Trương Định': 'Trương Định',
#  'Mộ Trạch': 'Mộ Trạch',
#  'dầu mỏ': 'Dầu mỏ',
#  'Ilya Prigogine': 'Ilya Prigogine',
#  'Cộng hoà Dân chủ Nhân dân Triều Tiên': 'Cộng hòa Dân chủ Nhân dân Triều Tiên',
#  'Thanh Hoá': 'Thanh Hóa',
#  'Buenos Aires': 'Buenos Aires',
#  'Nguyễn Hoàng': 'Nguyễn Hoàng',
#  'chợ Phong Lưu': 'Chợ Khau Vai',
#  'Hoa Kỳ': 'Hoa Kỳ',
#  'Paris': 'Paris',
#  'tại Đà Nẵng': 'Đà Nẵng',
#  'Johannesburg': 'Johannesburg',
#  'ở Honolulu , Hawaii': 'Honolulu',
#  'Bắc Băng Dương': 'Bắc Băng Dương',
#  ' đỉnh Everest': 'Everest',
#  'Tần Thuỷ Hoàng': 'Tần Thủy Hoàng',
#  'huyện Thanh Trì': 'Thanh Trì',
#  'đạo Cơ Đốc': 'Kitô giáo',
#  'Isaac': 'Isaac (ca sĩ)',
#  'rừng rậm': 'Rừng rậm',
#  'Lịch triều hiến chương loại chí': 'Lịch triều hiến chương loại chí',
#  'Cần Thơ': 'Cần Thơ',
#  'Hồ Xuân Hương': 'Hồ Xuân Hương (Đà Lạt)',
#  'Gambia': 'Gambia',
#  'thủ đô Paris': 'Paris',
#  'Lê Văn Thịnh': 'Lê Văn Thịnh',
#  'sông Hương': 'Sông Hương',
#  'Thái Bình hưng bảo': 'Tiền Thái Bình hưng bảo',
#  'trấn Sơn Nam Hạ thành trấn Nam Định': 'Sơn Nam (trấn)',
#  'Hàn Quốc': 'Hàn Quốc',
#  'thành phố Kyiv': 'Kyiv',
#  'Lê Lợi': 'Lê Thái Tổ',
#  'Nagasaki': 'Nagasaki',
#  'Chùa Linh Phong': 'Chùa Linh Phong (Bình Định)',
#  'vua Hùng': 'Hùng Vương',
#  'huyện Đồng Văn': 'Đồng Văn',
#  'Philadelphia': 'Philadelphia',
#  'Bản giao hưởng số 41': 'Giao hưởng số 41 (Mozart)',
#  'thành phố Mỹ Tho': 'Mỹ Tho',
#  'Trần Hưng Đạo': 'Trần Hưng Đạo',
#  'Kim Jong-un': 'Kim Jong-un',
#  'cải bắp': 'Cải bắp',
#  'huyện Lôi Dương': 'Lôi Dương',
#  'thuộc phần bờ tây vịnh Bắc Bộ tại khu vực biển Đông Bắc Việt Nam': 'Vịnh Bắc Bộ',
#  'Cầu Tân Đệ': 'Cầu Tân Đệ',
#  'lưu vực sông Amazon của Nam Mỹ': 'Sông Amazon',
#  'Lý Nhân Tông': 'Lý Nhân Tông',
#  'Cố Mạn': 'Cố Mạn',
#  'Trung Quốc': 'Trung Quốc',
#  'gặp đội tuyển Tây Ban Nha': 'Đội tuyển bóng đá quốc gia Tây Ban Nha',
#  'rương Quang Nghĩa': 'Trương Quang Nghĩa',
#  'Trường Giang': 'Trường Giang',
#  'Hà Nội': 'Hà Nội',
#  'Thi Sách': 'Thi Sách',
#  'HTC Corporation': 'HTC',
#  'Ngô Quyền': 'Ngô Quyền',
#  'Nhà bác học Hy Lạp cổ đại Archimedes': 'Archimedes',
#  'Đại Cồ Việt': 'Đại Cồ Việt',
#  'vua Chế Mân': 'Chế Mân',
#  'người Champa': 'Chăm Pa',
#  'Cyrus II Đại đế': 'Cyrus Đại đế',
#  'Chủ tịch Hồ Chí Minh': 'Hồ Chí Minh',
#  'Salzburg': 'Salzburg',
#  'Einstein': 'Albert Einstein',
#  'Trịnh Giang': 'Trịnh Giang',
#  'Trần Nhân Tông': 'Trần Nhân Tông',
#  'Ninh Bình': 'Ninh Bình',
#  'châu Mỹ': 'Châu Mỹ',
#  'Nhật Bản': 'Nhật Bản',
#  'thủ môn': 'Thủ môn (bóng đá)',
#  'Bến Tre': 'Bến Tre',
#  'Lạng Sơn': 'Lạng Sơn',
#  'Tây Ninh': 'Tây Ninh',
#  'Thành phố Hồ Chí Minh ': 'Thành phố Hồ Chí Minh',
#  'Nguyễn Văn Thương': 'Nguyễn Văn Thương (quân nhân)',
#  'An Giang': 'An Giang',
#  'đảo Phú Quốc': 'Phú Quốc',
#  'Nam Anh': 'Nam Anh (xã)',
#  'Yuri Alekseievich Gagarin': 'Yuri Alekseyevich Gagarin',
#  'Fujiko F. Fujio': 'Fujiko Fujio',
#  'New Zealand': 'New Zealand',
#  'gà HW': 'Gà Hisex',
#  'Nam Định': 'Nam Định',
#  'Quần thể danh thắng Tràng An': 'Quần thể danh thắng Tràng An',
#  'Nauru': 'Nauru',
#  'Quy Nhơn': 'Quy Nhơn',
#  'Trịnh Kiểm': 'Trịnh Kiểm',
#  'tỉnh Điện Biên': 'Điện Biên',
#  'Đại y Thiền sư Tuệ Tĩnh': 'Tuệ Tĩnh',
#  'Đường Thái Tông Lý Thế Dân': 'Đường Thái Tông',
#  'Tào Tháo': 'Tào Tháo',
#  'trong địa phận tỉnh Long An': 'Long An',
#  'tỉnh Nam Hà': 'Nam Hà (tỉnh)',
#  'Chữ nôm': 'Chữ Nôm',
#  'Nghệ An': 'Nghệ An',
#  'Lãnh tụ Tối cao Iran': 'Lãnh tụ Tối cao Iran',
#  'huyện Na Rì': 'Bắc Kạn',
#  'Núi Sam': 'Núi Sam (phường)',
#  'Khánh Hoà': 'Khánh Hòa',
#  'thành phố Bảo Lộc': 'Bảo Lộc',
#  'Hải Dương': 'Hải Dương',
#  'Huệ Tông': 'Lý Huệ Tông',
#  'tại xã Tân Trạch , huyện Bố Trạch , tỉnh Quảng Bình , Việt Nam được coi là hang động tự nhiên lớn nhất thế giới .': 'Tân Trạch, Bố Trạch',
#  'Tây Ban Nha': 'Tây Ban Nha',
#  'Hưng Đạo đại vương Trần Quốc Tuấn': 'Trần Hưng Đạo',
#  'sông Vu Gia': 'Sông Vu Gia',
#  'Phật giáo': 'Phật giáo',
#  'Cộng hòa Dân chủ Congo': 'Cộng hòa Dân chủ Congo',
#  'là Di sản văn hoá phi vật thể đại diện của nhân loại': 'Di sản văn hóa phi vật thể',
#  'Trần Cảnh': 'Trần Thái Tông',
#  'Nga': 'Nga',
#  'Thái Bình Dương': 'Thái Bình Dương',
#  'Momofuku Ando': 'Andō Momofuku',
#  'Đông Nam Á': 'Đông Nam Á',
#  'Lạc Long Quân': 'Lạc Long Quân',
#  'Vườn quốc gia Cúc Phương': 'Vườn quốc gia Cúc Phương',
#  'ở trung tâm đồng bằng sông Hồng': 'Đồng bằng sông Hồng',
#  'huyện Duy Xuyên': 'Duy Xuyên',
#  'trên bán đảo Triều Tiên': 'Bán đảo Triều Tiên',
#  'Thuỷ điện Sơn La': 'Nhà máy thủy điện Sơn La',
#  'thủ đô Reykjavík': 'Reykjavík',
#  ' tỉnh Hà Tĩnh': 'Hà Tĩnh',
#  'Lực lượng vũ trang': 'Lực lượng vũ trang',
#  'John Napier': 'John Napier',
#  'tại Hải Phòng': 'Hải Phòng',
#  'chống tăng': 'Xe tăng',
#  'Pyotr Ilyich Tchaikovsky': 'Pyotr Ilyich Tchaikovsky',
#  'núi Hàm Rồng': 'Núi Hàm Rồng (Sa Pa)',
#  'Tây Nguyên , miền Trung Việt Nam .': 'Tây Nguyên',
#  'Tỉnh Kiên Giang': 'Kiên Giang',
#  'Đồng Tháp': 'Đồng Tháp',
#  'Tương Bần': 'Tương Bần',
#  'nằm ở đầu đường Hoàng Mai , phường Hoàng Văn Thụ , quận Hoàng Mai , Hà Nội': 'Hoàng Văn Thụ, quận Hoàng Mai',
#  'Pháo hoa hoặc Pháo bông': 'Pháo hoa',
#  'người làng Phú Thị, huyện Gia Lâm, tỉnh Bắc Ninh; nay thuộc xã Phú Thị, huyện Gia Lâm, Hà Nội.': 'Bắc Ninh',
#  'Nguyễn Thị Duệ': 'Nguyễn Thị Duệ',
#  'Trại rắn Đồng Tâm': 'Trại rắn Đồng Tâm',
#  'Berlin': 'Berlin',
#  'Margaret Mitchell': 'Margaret Mitchell',
#  'Sông và Núi Ural': 'Sông Ural',
#  'Salar de Uyuni hay Salar de Tunupa': 'Salar de Uyuni',
#  'Vườn quốc gia Bái Tử Long': 'Vườn quốc gia Bái Tử Long',
#  'Ando Momofuku': 'Andō Momofuku',
#  'trên núi Nghĩa Lĩnh, giữa đất Phong Châu, ngày nay là xã Hy Cương, thành phố Việt Trì, tỉnh Phú Thọ': 'Đền Hùng',
#  'huyện Đức Trọng': 'Đức Trọng',
#  'Tây du ký': 'Tây du ký',
#  'thời Gia Long': 'Gia Long',
#  'tỉnh Hà Giang': 'Hà Giang',
#  'thịt chim bồ câu': 'Thịt bồ câu',
#  'Muối tôm': 'Muối tôm',
#  'Sông Cầu': 'Sông Cầu',
#  'Niklaus Wirth': 'Niklaus Wirth',
#  'toạ lạc tại số 1681 đại lộ Broadway , khu Manhattan , New York , Hoa Kỳ .': 'Manhattan',
#  'đậu đen': 'Đậu đen',
#  'huyện Thạch Thất': 'Thạch Thất',
#  'sao Mộc': 'Sao Mộc',
#  'Thi': 'Thi Sách',
#  'Bảo tàng các dân tộc Việt Nam': 'Bảo tàng các dân tộc Việt Nam tại Đắk Lắk',
#  'Bán đảo Triều Tiên': 'Bán đảo Triều Tiên',
#  'Nguyễn Án': 'Nguyễn Án',
#  'Sóc Trăng': 'Sóc Trăng',
#  'vua Gia Long': 'Gia Long',
#  'sông Đà': 'Sông Đà',
#  'huyện Hải Lăng': 'Hải Lăng',
#  'Cairo': 'Cairo',
#  'Hà Giang': 'Hà Giang',
#  'Vương quốc Bhutan': 'Bhutan',
#  'vua Lê Thánh Tông': 'Lê Thánh Tông',
#  'thành phố Nairobi': 'Nairobi',
#  'Anh': 'Anh',
#  'Lê Thánh Tông': 'Lê Thánh Tông',
#  'hoàng hậu Nam Phương': 'Nam Phương Hoàng hậu',
#  'Cao nguyên đá Đồng Văn': 'Cao nguyên đá Đồng Văn',
#  'huyện Vân Đồn ( Quảng Ninh )': 'Vân Đồn',
#  'Satoshi Nakamoto': 'Satoshi Nakamoto',
#  'Russell': 'Bertrand Russell',
#  'châu Á': 'Châu Á',
#  'Nguyễn Sơn Hà': 'Nguyễn Sơn Hà',
#  'Orkhon': 'Sông Orkhon',
#  'Delhi': 'Delhi',
#  'Đài phát thanh Sài Gòn': 'Đài Vô tuyến Việt Nam',
#  'Martin Luther King': 'Martin Luther King',
#  'tỉnh Đắk Lắk': 'Đắk Lắk',
#  'tỉnh Ninh Bình': 'Ninh Bình',
#  'Kingston': 'Kingston, Jamaica',
#  'Bà Rịa-Vũng Tàu': 'Bà Rịa – Vũng Tàu',
#  'Trà Vinh': 'Trà Vinh',
#  ' động Hoa Lư thuộc xã Gia Hưng - huyện Gia Viễn - tỉnh Ninh Bình': 'Ninh Bình',
#  'sông Sê San': 'Sông Sê San',
#  'Chu Văn An': 'Chu Văn An',
#  'Đặng Trọng Thăng': 'Đặng Trọng Thăng',
#  'vua Lê Đại Hành': 'Lê Đại Hành',
#  'Sicilia': 'Sicilia',
#  'Juan Carlos': 'Juan Carlos I của Tây Ban Nha',
#  'Trần Thái Tông': 'Trần Thái Tông',
#  'huyện Thoại Sơn': 'Thoại Sơn',
#  'thôn Phước Long, xã Chương Tín, huyện Phong Lộc (nay là xã Vạn Ninh, huyện Quảng Ninh, tỉnh Quảng Bình': 'Quảng Bình',
#  'do Nhật Bản thiết kế': 'Nhật Bản',
#  'bác sĩ Alexandre Yersin': 'Alexandre Yersin',
#  'Lưu Bị': 'Lưu Bị',
#  'trang mạng Twitter': 'Twitter',
#  'nằm trên cao nguyên Lâm Viên': 'Cao nguyên Lâm Viên',
#  'HTC': 'HTC',
#  'Indonesia': 'Indonesia',
#  'châu Đại Dương': 'Châu Đại Dương',
#  'Nam Phi': 'Cộng hòa Nam Phi',
#  'Sao Thuỷ hay Thuỷ tinh': 'Sao Thủy',
#  'Võ tắc thiên': 'Võ Tắc Thiên',
#  'Nicosia': 'Nicosia',
#  'Lăng Khải Định': 'Lăng Khải Định',
#  'Dubai': 'Dubai',
#  'Bắc Kạn': 'Bắc Kạn',
#  'Cà Mau': 'Cà Mau',
#  'Chí Linh': 'Chí Linh',
#  'axit amin': 'Amino acid',
#  'Ả Rập Xê Út': 'Ả Rập Xê Út',
#  'Alexei Leonov': 'Aleksey Arkhipovich Leonov',
#  'Đặng Xuân': 'Đặng (họ)',
#  'Khu di tích Pác Bó': 'Khu di tích Pác Bó',
#  'Nguyễn Thúc Mậu': 'Nguyễn Thúc Mậu',
#  'Nằm cách Hà Nội 320  km trên trục Quốc lộ 6 Hà Nội - Sơn La - Điện Biên , Sơn La là một tỉnh nằm sâu trong nội địa': 'Sơn La',
#  'Đức': 'Đức',
#  'CHDCND Lào': 'Lào',
#  'thành phố Buôn Ma Thuột': 'Buôn Ma Thuột',
#  'Ấn Độ': 'Ấn Độ',
#  'Amber Heard': 'Amber Heard',
#  'đổ ra biển Địa Trung Hải': 'Địa Trung Hải',
#  'Tôn Đức Thắng': 'Tôn Đức Thắng',
#  'Đèo Hải Vân': 'Đèo Hải Vân',
#  'Lào Cai': 'Lào Cai',
#  'Ngũ Hành Sơn': 'Ngũ Hành Sơn (quận)',
#  'Khởi nghĩa Hương Khê': 'Khởi nghĩa Hương Khê',
#  'Tỏi Lý Sơn': 'Tỏi Lý Sơn',
#  'tọa lạc trên quảng trường Cách mạng tháng Tám': 'Quảng trường Cách mạng tháng Tám',
#  'Sông Amazon': 'Sông Amazon',
#  'Thái thượng hoàng Trần Nhân Tông ': 'Trần Nhân Tông',
#  'tỉnh Hà Tĩnh': 'Hà Tĩnh',
#  'Tết Thượng Nguyên, hay Tết Trạng nguyên, ngày xưa là dịp nhà vua hội họp các ông Trạng để thết tiệc và mời vào vườn Thượng Uyển thăm hoa, ngắm cảnh, làm thơ': 'Tết Nguyên tiêu',
#  'Manila': 'Manila',
#  'Phan Ngọc Thọ': 'Phan Ngọc Thọ',
#  'tỉnh Bình Thuận': 'Bình Thuận',
#  'Cristoforo Colombo': 'Cristoforo Colombo',
#  'Đảo Okinawa': 'Okinawa (đảo)',
#  'Cảng Thượng Hải (Shanghai)': 'Cảng Thượng Hải',
#  'thành phố New York': 'Thành phố New York',
#  'nhà Nguyễn': 'Nhà Nguyễn',
#  'Chợ Ngã Bảy': 'Chợ nổi Ngã Bảy',
#  'Thành phố New York': 'Thành phố New York',
#  'sông Cửu Long': 'Sông Cửu Long',
#  'Hải Phòng': 'Hải Phòng',
#  'Thái': 'Thái',
#  'Trần Dụ Tông': 'Trần Dụ Tông',
#  'Lý Anh Tông': 'Lý Anh Tông',
#  'làng Phù Ủng': 'Phù Ủng',
#  'Tượng Nữ thần Tự do': 'Tượng Nữ thần Tự do',
#  'tàn cuộc': 'Tàn cuộc (cờ vua)',
#  'Mark Twain': 'Mark Twain',
#  'Vườn Quốc gia Cúc Phương': 'Vườn quốc gia Cúc Phương',
#  'Eros': 'Eros',
#  'Réunion': 'Réunion',
#  'phố Ngũ Xã và đường Nguyễn Khắc Hiếu': 'Ngũ Xã',
#  ' tỉnh Nghệ An': 'Nghệ An',
#  'Bern hay Berne': 'Bern',
#  'nằm ở cực bắc của Trung Bộ Việt Nam': 'Bắc Trung Bộ',
#  'Trương Quang Nghĩa': 'Trương Quang Nghĩa',
#  'Vua Minh Mạng ': 'Minh Mạng',
#  'Athens': 'Athens',
#  'Thành phố Tân An': 'Tân An',
#  'Vườn quốc gia Bidoup': 'Vườn quốc gia Bidoup – Núi Bà',
#  'Chùa Hang': 'Chùa Cổ Thạch',
#  'Sofia': 'Sofia',
#  'Zürich': 'Zürich',
#  'Azerbaijan': 'Azerbaijan',
#  'là thành viên sáng lập Hiệp hội Viện Đại học Bắc Mỹ': 'Hiệp hội Viện Đại học Mỹ',
#  'xã Văn Lộc , huyện Hậu Lộc , tỉnh Thanh Hoá': 'Thanh Hóa',
#  'quê gốc tại Điện Thọ , huyện Điện Bàn , tỉnh Quảng Nam': 'Điện Thọ',
#  'làng Tiên Điền': 'Tiên Điền',
#  'John Langdon Down': 'John Langdon Down',
#  'Đoàn Tử Quang': 'Đoàn Tử Quang',
#  'sóng ngắn': 'Vô tuyến sóng ngắn',
#  'Ai Cập': 'Ai Cập',
#  'Địa hình núi cao ( trên 2.000 m )': 'Núi',
#  'xã Văn Nho': 'Văn Nho',
#  'Ngoại trưởng Joachim von Ribbentrop': 'Joachim von Ribbentrop',
#  ' Địa Trung Hải': 'Địa Trung Hải',
#  'tiền đạo': 'Tiền đạo (bóng đá)',
#  'huyện Cao Phong': 'Cao Phong',
#  'Trần Thị Dung': 'Linh Từ quốc mẫu',
#  'Ngũ Đại Hồ': 'Ngũ Đại Hồ',
#  'Italy': 'Ý',
#  'Louis XIII': 'Louis XIII của Pháp',
#  'miền Nam': 'Miền Nam (Việt Nam)',
#  'Sankt Peterburg': 'Sankt-Peterburg',
#  'Gà Mía': 'Gà Mía',
#  'Lý Chiêu Hoàng': 'Lý Chiêu Hoàng',
#  'sông Mêkông': 'Mê Kông',
#  'Cộng hoà Hà Lan': 'Cộng hòa Hà Lan',
#  'phía nam': 'Hướng Nam',
#  'Trần Nghệ Tông': 'Trần Nghệ Tông',
#  'Tuyên Từ Hoàng thái hậu': 'Tuyên Từ Hoàng hậu',
#  'Jean Baptiste Louis Pierre': 'Jean Baptiste Louis Pierre',
#  'Chế Củ': 'Chế Củ',
#  'Campuchia': 'Campuchia',
#  'penicillin': 'Penicillin',
#  'Nam Trung Bộ': 'Duyên hải Nam Trung Bộ',
#  'Nguyễn Tế Công hay Nguyễn Tề Công': 'Nguyễn Tế Công',
#  'Alexandros Đại Đế': 'Alexandros Đại đế',
#  'nhà Tần': 'Nhà Tần',
#  'Sân bay quốc tế Tân Sơn Nhất': 'Sân bay quốc tế Tân Sơn Nhất',
#  'huyện Quỳnh Phụ': 'Quỳnh Phụ',
#  'Bản đồ Hồng Đức': 'Bản đồ Hồng Đức',
#  'Cửu Hoa sơn': 'Cửu Hoa (núi)',
#  'vùng Phú Thọ': 'Phú Thọ',
#  'châu Phi': 'Châu Phi',
#  'Malé': 'Malé',
#  'Ba Bể': 'Hồ Ba Bể',
#  'Châu Á': 'Châu Á',
#  'ở trung tâm vùng Tây Nguyên , miền Trung Việt Nam .': 'Tây Nguyên',
#  'Bình Phước': 'Bình Phước',
#  'Bảo Thắng': 'Bảo Thắng',
#  'Đèo Pha Đin': 'Đèo Pha Đin',
#  'Tây Thi': 'Tây Thi',
#  'Canada': 'Canada',
#  'Mauna Loa': 'Mauna Loa',
#  'quân Lâm Ấp': 'Lâm Ấp',
#  'Nhật': 'Nhật Bản',
#  'Tehran': 'Tehran',
#  'Xerxes Đại đế': 'Xerxes I',
#  'tả ngạn của sông Trà Khúc ': 'Sông Trà Khúc',
#  'Khiêm vương Mạc Kính Điển': 'Mạc Kính Điển',
#  'Nguyễn Văn Thoại': 'Thoại Ngọc hầu',
#  'quận Ngũ Nguyên': 'Ngũ Nguyên',
#  'Long Xuyên': 'Long Xuyên',
#  'Nguyễn Trãi': 'Nguyễn Trãi',
#  'Greenland': 'Greenland',
#  'Khánh Hòa': 'Khánh Hòa',
#  'Iraq': 'Iraq',
#  'Vũ Đăng Toàn': 'Vũ Đăng Toàn',
#  'Châu bản triều Nguyễn': 'Châu bản triều Nguyễn',
#  'Việt Nam': 'Chiến tranh Việt Nam',
#  'chùa Linh Phước ở Đà Lạt ': 'Chùa Linh Phước',
#  'Waler Fleming': 'Walther Flemming',
#  'Tây Âu': 'Tây Âu',
#  'tỉnh Quảng Bình': 'Quảng Bình',
#  'Chùa Xiêm Cán': 'Chùa Xiêm Cán',
#  'tỉnh Ninh Thuận': 'Ninh Thuận',
#  'núi Trung Kì': 'Dãy Trường Sơn',
#  'Simón Bolívar': 'Simón Bolívar',
#  'Tô Lâm': 'Tô Lâm',
#  'vua Đinh Tiên Hoàng': 'Đinh Tiên Hoàng',
#  'Thái Lan': 'Thái Lan',
#  'Bắc Âu': 'Bắc Âu',
#  'nước Pháp': 'Pháp',
#  'Zanzibar': 'Zanzibar',
#  'tỉnh Hưng Yên': 'Hưng Yên',
#  'tại Úc,\tCanberra': 'Canberra',
#  'Hồi giáo': 'Hồi giáo',
#  'Henry VI': 'Henry VI của Anh',
#  'Lê Thái Tổ': 'Lê Thái Tổ',
#  'André Trương Trọng Thi': 'Trương Trọng Thi',
#  'Thân Nhân Trung': 'Thân Nhân Trung',
#  'vua Kiến Phúc': 'Kiến Phúc',
#  'Thành phố Vị Thanh': 'Vị Thanh',
#  'Dustin Moskovitz': 'Dustin Moskovitz',
#  'Chùa Thiếu Lâm': 'Chùa Thiếu Lâm',
#  'ở Luân Đôn': 'Luân Đôn',
#  'Tây Tạng': 'Tây Tạng',
#  'vịnh Thái Lan': 'Vịnh Thái Lan',
#  'Tô Hoài': 'Tô Hoài',
#  'tỉnh Thanh Hoá': 'Thanh Hóa',
#  'Yousafzai': 'Malala Yousafzai',
#  'Hy Lạp': 'Hy Lạp',
#  'Vườn quốc gia Chư Mom Ray': 'Vườn quốc gia Chư Mom Ray',
#  'thủ đô Zagreb': 'Zagreb',
#  'Bắc Phi': 'Bắc Phi',
#  'Lý Thường Kiệt': 'Lý Thường Kiệt',
#  'Ấn Độ giáo': 'Ấn Độ giáo',
#  'U Nu': 'U Nu',
#  'Honolulu , Hawaii': 'Honolulu',
#  'Anh ': 'Anh',
#  'Bắc Ninh ': 'Bắc Ninh',
#  'Nguyễn Thị Minh Lý': 'Nguyễn Thị Minh Lý',
#  'Phú Yên': 'Phú Yên',
#  'viêm gan siêu vi C': 'Viêm gan C',
#  'sông Hàn': 'Sông Hàn',
#  'nhà Mạc': 'Nhà Mạc',
#  'Cụm đảo Hòn Khoai': 'Quần đảo Hòn Khoai',
#  'Vườn quốc gia Núi Chúa': 'Vườn quốc gia Núi Chúa',
#  'Apollo 11': 'Apollo 11',
#  'Văn Tiến Dũng': 'Văn Tiến Dũng',
#  'Liên bang Nga': 'Nga',
#  'Liên Bang Nga': 'Nga',
#  'Burj Khalifa': 'Burj Khalifa',
#  'Công viên địa chất Cao nguyên đá Đồng Văn': 'Cao nguyên đá Đồng Văn',
#  'Gangkhar Puensum': 'Gangkhar Puensum',
#  'tỉnh Khánh Hòa': 'Khánh Hòa',
#  'Lê Trang Tông': 'Lê Trang Tông',
#  'rãnh Mariana': 'Rãnh Mariana',
#  'Tuy Hoà': 'Tuy Hòa',
#  'Helsinki': 'Helsinki',
#  'Lâm Đồng': 'Lâm Đồng',
#  'vùng đồng bằng sông Hồng ': 'Đồng bằng sông Hồng',
#  'tỉnh Nghệ An': 'Nghệ An',
#  'kim tự tháp bậc thang của pharaon Djoser': 'Kim tự tháp Djoser',
#  'Khu di tích nhà Trần tại Đông Triều': 'Khu di tích nhà Trần tại Đông Triều',
#  'Tô Vĩnh Diện': 'Tô Vĩnh Diện',
#  'Vạn Niên Cơ': 'Lăng Tự Đức',
#  'nhà Trần ( thế kỷ 13 )': 'Nhà Trần',
#  'khởi nghĩa Ba Đình': 'Khởi nghĩa Ba Đình',
#  'Nguyễn Công Trứ': 'Nguyễn Công Trứ',
#  'tỉnh Gyeongsang': 'Gyeongsang Nam',
#  'thành phố Hải Phòng .': 'Hải Phòng',
#  'Tango': 'Tango (vũ điệu)',
#  'đầm Dạ Trạch': 'Đầm Dạ Trạch',
#  'Albert Einstein': 'Albert Einstein',
#  'chùa Đồng': 'Chùa Đồng',
#  'Thác Niagara': 'Thác Niagara',
#  'Artemis': 'Artemis',
#  'công viên Champ-de-Mars': 'Champ-de-Mars',
#  'Vườn quốc gia Cát Bà': 'Vườn quốc gia Cát Bà',
#  'Châu Đại Dương': 'Châu Đại Dương',
#  'Dương Vân Nga': 'Đại Thắng Minh Hoàng hậu',
#  'nước Anh': 'Anh',
#  'Hải đăng Hòn Dấu': 'Hải đăng Hòn Dấu',
#  'Tháp Nhạn': 'Tháp Nhạn',
#  'Vua Lý Thần Tông': 'Lý Thần Tông',
#  'Nguyễn Lữ': 'Nguyễn Lữ',
#  'Đảo Hòn Tre': 'Hòn Tre (Khánh Hòa)',
#  'khu dự trữ sinh quyển thế giới': 'Khu dự trữ sinh quyển thế giới',
#  'Trận Như Nguyệt': 'Trận Như Nguyệt',
#  'quân Ngô': 'Nhà Ngô',
#  'thành phố Đà Lạt': 'Đà Lạt',
#  'ở Tuyên Quang': 'Tuyên Quang',
#  'Võ Thành Thống': 'Võ Thành Thống',
#  'Tỉnh Cao Bằng': 'Cao Bằng',
#  'bánh mì nướng': 'Bánh mì nướng',
#  'đào kênh Vĩnh Tế ( Châu Đốc , An Giang ) ': 'Kênh Vĩnh Tế',
#  'Helsinki.': 'Helsinki',
#  'Hồ Nguyên Trừng': 'Hồ Nguyên Trừng',
#  'Thuý Kiều': 'Thúy Kiều',
#  'Nguyên Hồng': 'Nguyên Hồng',
#  'Sao Kim': 'Sao Kim',
#  'Vác-sa-va': 'Warszawa',
#  'Nick Út': 'Nick Út',
#  'Buôn Ma Thuột': 'Đắk Lắk',
#  'từ khu ngoại ô Buenos Aires': 'Buenos Aires',
#  'Milano': 'Milano',
#  'Đế quốc Mông Cổ': 'Đế quốc Mông Cổ',
#  'Mỹ': 'Hoa Kỳ',
#  'Barcelona': 'Barcelona',
#  'Singapore': 'Singapore',
#  'Rice': 'Condoleezza Rice',
#  'Đề Thám': 'Hoàng Hoa Thám',
#  'phim hoạt hình': 'Phim hoạt hình',
#  'bán đảo Iberia': 'Bán đảo Iberia',
#  'Homer': 'Homeros',
#  'Đỗ Cảnh Thạc': 'Đỗ Cảnh Thạc',
#  'Thành phố Luxembourg hay Thành phố Luxembourg': 'Luxembourg (thành phố)',
#  'châu Phi ': 'Châu Phi',
#  'Đất rừng phương Nam"': 'Đất rừng phương Nam',
#  'vùng Đông Nam Bộ': 'Đông Nam Bộ',
#  'Tự Đức': 'Tự Đức',
#  'Doãn Nho': 'Doãn Nho',
#  'vua Trần Thái Tông': 'Trần Thái Tông',
#  'tại hành cung Vũ Lâm': 'Hành cung Vũ Lâm',
#  'Quận 11': 'Quận 11',
#  'quê tại làng Bột Thượng, trấn Hoằng Hóa, tỉnh Thanh Hóa, nay thuộc thôn Hưng Tiến, xã Hoằng Lộc, huyện Hoằng Hóa, tỉnh Thanh Hóa': 'Thanh Hóa',
#  'Dương Tam Kha': 'Dương Tam Kha',
#  'Rowling': 'J. K. Rowling',
#  'Abraham Lincoln': 'Abraham Lincoln',
#  'đồng bằng sông Cửu Long': 'Đồng bằng sông Cửu Long',
#  'Hoàng Việt luật lệ hay còn gọi là luật Gia Long': 'Hoàng Việt luật lệ',
#  'Đế quốc Đông La Mã': 'Đế quốc Đông La Mã',
#  'Duyên hải Nam Trung Bộ': 'Duyên hải Nam Trung Bộ',
#  'Châu Nam Cực': 'Châu Nam Cực',
#  'Barack Hussein Obama II': 'Barack Obama',
#  ' Nghệ An': 'Nghệ An',
#  'Chiêm Thành': 'Chiêm Thành',
#  'Trương Khiên': 'Trương Khiên',
#  'Thomas L. Friedman': 'Thomas Friedman',
#  'đảo Cô Tô': 'Cô Tô',
#  'bột gạo': 'Bột gạo',
#  'Lê Đại Hành': 'Lê Đại Hành',
#  'quảng trường Cách mạng tháng Tám': 'Quảng trường Cách mạng tháng Tám',
#  'Amazon': 'Sông Amazon',
#  'Ulaanbaatar': 'Ulaanbaatar',
#  'nằm giữa bán đảo Mã Lai và đảo Sumatra': 'Sumatra',
#  'Quảng Bình': 'Quảng Bình',
#  'Kiên Giang': 'Kiên Giang',
#  'Sao Hỏa': 'Sao Hỏa',
#  'San José': 'San José, Costa Rica',
#  'Trí Bá ': 'Tuân Dao',
#  'Yuri Gagarin ': 'Yuri Alekseyevich Gagarin',
#  'Cuzco': 'Cuzco',
#  'sông Bến Hải': 'Sông Bến Hải',
#  'Menlo Park , California': 'Menlo Park, California',
#  'Hoàng thái hậu Từ Dụ': 'Từ Dụ',
#  'Haifa': 'Haifa',
#  'Hồ Tuyền Lâm': 'Hồ Tuyền Lâm',
#  'đèn đỏ': 'Đèn đỏ',
#  'Wirth': 'Niklaus Wirth',
#  'Quận 1': 'Quận 1',
#  'Bắc Ireland': 'Bắc Ireland',
#  'Phạm Tuân': 'Phạm Tuân',
#  'Edison': 'Thomas Edison',
#  'Ngô Sĩ Liên': 'Ngô Sĩ Liên',
#  'sườn núi Lớn': 'Núi Lớn',
#  'Trần Bình Trọng': 'Trần Bình Trọng',
#  'ở Đà Nẵng': 'Đà Nẵng',
#  'nhà Hán': 'Nhà Hán',
#  'Dân ca quan họ': 'Quan họ',
#  'tỉnh Kiên Giang': 'Kiên Giang',
#  'Cộng hoà Séc': 'Cộng hòa Séc',
#  'Glarus': 'Glarus (bang)',
#  'Bàu Tró': 'Bàu Tró',
#  'Tây du ký "': 'Tây du ký',
#  'Myanmar': 'Myanmar',
#  'Xích Quỷ': 'Xích Quỷ',
#  'Zeus': 'Zeus',
#  'tên gọi khác là Trung tâm Đà Lạt , được đặt tên Lâm Viên': 'Quảng trường Lâm Viên',
#  'núi Nhạn Tháp , núi Bảo Tháp , núi Tháp Dinh hay núi Khỉ': 'Núi Nhạn',
#  'thị xã Ninh Hoà': 'Ninh Hòa',
#  'tỉnh Nghĩa Bình': 'Nghĩa Bình (tỉnh)',
#  'VNG': 'VNG',
#  'sông Cánh Hòm': 'Sông Cánh Hòm',
#  'tại khu vực tây nam của Thái Bình Dương': 'Thái Bình Dương',
#  'nam Âu': 'Nam Âu',
#  'Jakarta': 'Jakarta',
#  'bán đảo Ả Rập': 'Bán đảo Ả Rập',
#  'Tổng thống': 'Tổng thống',
#  'trứng ốp la': 'Trứng ốp la',
#  'Peru': 'Peru',
#  'Mỏ Cày': 'Mỏ Cày',
#  'Vườn quốc gia Bến En': 'Vườn quốc gia Bến En',
#  'Hồ Baikal': 'Hồ Baikal',
#  'triều nhà Nguyễn': 'Nhà Nguyễn',
#  '" SpaceX "': 'SpaceX',
#  'dưới triều vua Minh Mạng': 'Minh Mạng',
#  'Chợ Ngã Bãy': 'Chợ nổi Ngã Bảy',
#  'Tại Svalbard': 'Svalbard',
#  'Sucre': 'Sucre',
#  'John Browning': 'John Browning',
#  'Dãy núi Hoàng Liên Sơn': 'Dãy núi Hoàng Liên Sơn',
#  'sông Paraná': 'Sông Paraná',
#  'Quốc lộ 10': 'Quốc lộ 10',
#  'Sơn La': 'Sơn La',
#  'Thành phố Hồ Chí Minh .': 'Thành phố Hồ Chí Minh',
#  'Thủ đô Hà Nội': 'Hà Nội',
#  'Cuba': 'Cuba',
#  'thành phố Kuwait': 'Thành phố Kuwait',
#  'Henriette Bùi Quang Chiêu': 'Henriette Bùi Quang Chiêu',
#  'Bãi Sau': 'Bãi Sau',
#  'do hãng phim Thượng Hải Đường Nhân sản xuất': 'Hãng phim Đường Nhân',
#  'Libya': 'Libya',
#  'tỉnh Tiền Giang': 'Tiền Giang',
#  'xã Tùng Ảnh': 'Tùng Ảnh',
#  'Thành Vatican': 'Thành Vatican',
#  'Lê Văn Khôi': 'Lê Văn Khôi',
#  'sông Nhật Tảo': 'Vàm Cỏ Đông',
#  'Skopje': 'Skopje',
#  'nằm trên đảo Ngọc của hồ Hoàn Kiếm ở Hà Nội, Việt Nam.': 'Hồ Hoàn Kiếm',
#  'Thụy Điển': 'Thụy Điển',
#  'Dubai Miracle Garden': 'Dubai Miracle Garden',
#  'Trần Trinh Trạch': 'Trần Trinh Trạch',
#  'Leonidas': 'Leonidas I',
#  'tại Nam Kinh': 'Nam Kinh',
#  'Võ Tắc Thiên': 'Võ Tắc Thiên',
#  'Trujillo': 'Trujillo, Peru',
#  'tỉnh Quảng Trị': 'Quảng Trị',
#  'Chiến dịch Phú Xuân 1786': 'Chiến dịch Phú Xuân 1786',
#  'nem nướng Ninh Hoà': 'Nem nướng',
#  'Trung Âu': 'Trung Âu',
#  'Nguyễn Nghiêu Tư': 'Nguyễn Nghiêu Tư',
#  'Hồ Chí Minh': 'Hồ Chí Minh',
#  'Capital Gate': 'Capital Gate',
#  'vua Đồng Khánh': 'Đồng Khánh',
#  'thành phố Phan Rang – Tháp Chàm': 'Phan Rang – Tháp Chàm',
#  'Tỉnh Ninh Bình': 'Ninh Bình',
#  'Hồ Thượng ': 'Hồ Thượng',
#  'Trường Giang hay sông Dương Tử': 'Trường Giang',
#  'Paul Allen': 'Paul Allen',
#  'Biên Hoà': 'Biên Hòa',
#  'Lê Trung Tông': 'Lê Trung Tông (Tiền Lê)',
#  'Nguyễn Bặc': 'Nguyễn Bặc',
#  'tỉnh Cà Mau': 'Cà Mau',
#  'sông Lam': 'Sông Lam',
#  'Sông Sài Gòn': 'Sông Sài Gòn',
#  ' tiếng Hy Lạp ': 'Tiếng Hy Lạp',
#  'Kiên Thái vương Nguyễn Phúc Hồng Cai': 'Đồng Khánh',
#  'nông nghiệp': 'Nông nghiệp',
#  'Chùa Cổ Lễ': 'Chùa Cổ Lễ',
#  'Andrus Ansip': 'Andrus Ansip',
#  'giáp với Tây Ban Nha': 'Tây Ban Nha',
#  'California': 'California',
#  'Sơn Trà': 'Sơn Trà (quận)',
#  'Đông Giang': 'Đông Giang (sông Trung Quốc)',
#  'đo điện tích Q trong hệ SI': 'Coulomb (đơn vị)',
#  'Kinh Dương Vương': 'Kinh Dương vương',
#  'thế kỷ 11': 'Thế kỷ 11',
#  'Lang Liêu': 'Lang Liêu',
#  ' Minh Mạng': 'Minh Mạng',
#  'Hoàng Xuân Sính': 'Hoàng Xuân Sính',
#  'thành phố Roma': 'Roma',
#  'Người Việt': 'Người Việt',
#  'Thổ Nhĩ Kỳ': 'Thổ Nhĩ Kỳ',
#  'Anne Boleyn': 'Anne Boleyn',
#  'nhà Lê sơ': 'Nhà Lê sơ',
#  'Nguyễn Tế Công': 'Nguyễn Tế Công',
#  'Thomas Newcomen': 'Thomas Newcomen',
#  'tỉnh Lâm Đồng': 'Lâm Đồng',
#  'Thành phố Stockholm': 'Stockholm',
#  'tiểu bang Hawaii': 'Hawaii',
#  'Nguyễn Phúc Ánh': 'Gia Long',
#  'Hoàng Hoa Thám': 'Hoàng Hoa Thám',
#  'Cổ Loa': 'Cổ Loa (xã)',
#  'Ottawa': 'Ottawa',
#  'Phidias': 'Phidias',
#  'Ở Phần Lan': 'Phần Lan',
#  'thôn Phước Long, xã Chương Tín, huyện Phong Lộc (nay là xã Vạn Ninh, huyện Quảng Ninh, tỉnh Quảng Bình)': 'Vạn Ninh, huyện Quảng Ninh',
#  'Ireland': 'đảo Ireland',
#  'Gia Long': 'Gia Long',
#  'Sao Thủy': 'Sao Thủy',
#  'sông Tigris': 'Tigris',
#  'Apple Computer': 'Apple Inc.',
#  'máy đo lượng mưa': 'Máy đo lượng mưa',
#  'Isfahan , Iran': 'Isfahan',
#  'Đinh Núp': 'Đinh Núp',
#  'Mikhail Kutuzov': 'Mikhail Illarionovich Kutuzov',
#  'François , Nam tước Englert': 'François Englert',
#  'Bae Yong Joon Việt Nam': 'Bae Yong-joon',
#  'Đuông': 'Đuông',
#  'Uruguay': 'Uruguay',
#  'Vua Lê Đại Hành': 'Lê Đại Hành',
#  'huyện Bát Xát': 'Bát Xát',
#  'Lưu Hữu Phước.': 'Lưu Hữu Phước',
#  'ở Đồng Tháp Mười , Việt Nam .': 'Đồng Tháp Mười',
#  'núi Ngự Bình': 'Núi Ngự Bình',
#  ' tỉnh Kiên Giang': 'Kiên Giang',
#  'Quảng Bình quan': 'Quảng Bình quan',
#  'Đàn Nam Giao': 'Đàn Nam Giao (triều Nguyễn)',
#  'Chiến tranh Punic': 'Chiến tranh Punic',
#  'tại thị xã Phú Thọ , tỉnh Phú Thọ': 'Phú Thọ (thị xã)',
#  'chủ yếu là chứa clorua natri ( NaCl )': 'Natri chloride',
#  'đèo Hải Vân': 'Đèo Hải Vân',
#  'vịnh Hạ Long ': 'Vịnh Hạ Long',
#  'Druk Gyalpo': 'Druk Gyalpo',
#  'Hoàng Ngọc Phách': 'Hoàng Ngọc Phách',
#  'Nguyễn Phúc Nguyên': 'Nguyễn Phúc Nguyên',
#  'Nam Hán': 'Nam Hán',
#  'chùa Thiên Mụ': 'Chùa Thiên Mụ',
#  'Phùng Xuân Nhạ': 'Phùng Xuân Nhạ',
#  'Philippines': 'Philippines',
#  'nước Thục': 'Thục (nước)',
#  'Hồ Quý Ly': 'Hồ Quý Ly',
#  'Biển Caribe': 'Biển Caribe',
#  'thị trấn Cái Rồng': 'Cái Rồng',
#  'Quảng Đông': 'Quảng Đông',
#  'Venezuela': 'Venezuela',
#  'Chiến tranh Xô-Đức. Thắng lợi to lớn của quân đội Liên Xô trên sông Volga': 'Chiến tranh Xô–Đức',
#  'Napoléon': 'Napoléon Bonaparte',
#  ' Đức ': 'Đức',
#  'thành phố Nha Trang': 'Nha Trang',
#  'Đế Minh': 'Đế Minh',
#  'Từ Phúc': 'Từ Phúc',
#  'Núi Cấm': 'Núi Cấm',
#  'bán đảo Triều Tiên': 'Bán đảo Triều Tiên',
#  'Nguyễn Sinh Sắc': 'Nguyễn Sinh Sắc',
#  'Yuri Gagarin': 'Yuri Alekseyevich Gagarin',
#  'Đại học Paris ( Sorbonne )': 'Đại học Paris',
#  'Sông Kim Ngưu cổ': 'Sông Kim Ngưu',
#  'biển Đông': 'Biển Đông',
#  'Lê Văn Thành': 'Lê Văn Thành (chính khách)',
#  'lầu Ông Hoàng': 'Lầu Ông Hoàng',
#  'Mumbai': 'Mumbai',
#  'Lý Cao Tông': 'Lý Cao Tông',
#  'làng Mạnh Chư, tục gọi là làng Dừa thuộc huyện Bình Lục, tỉnh Hà Nam.': 'Hà Nam',
#  ' hình chữ nhật': 'Hình chữ nhật',
#  'Đắk Lắk': 'Đắk Lắk',
#  'Tôn Sĩ Nghị': 'Tôn Sĩ Nghị',
#  'Ong chúa': 'Ong chúa',
#  'huyện Mường La': 'Mường La',
#  'tước Vương': 'Vương tước',
#  'Trung Á': 'Trung Á',
#  'Bán đảo Scandinavie': 'Bán đảo Scandinavia',
#  'Liên Xô ': 'Liên Xô',
#  'cuốn Catalan Atlas': 'Catalan Atlas',
#  'New York': 'New York (tiểu bang)',
#  'Oleksiy Mykhaylychenko': 'Oleksiy Oleksandrovich Mykhailychenko',
#  'Hán Thiếu Đế Lưu Biện': 'Lưu Biện',
#  'công chúa Huyền Trân': 'Huyền Trân Công chúa',
#  'Khương Tăng Hội': 'Khương Tăng Hội',
#  'Rãnh Mariana': 'Rãnh Mariana',
#  'nhân mã Cheiron': 'Chiron (thần thoại)',
#  'Madrid': 'Madrid',
#  'Nguyễn Đình Chiểu': 'Nguyễn Đình Chiểu',
#  'Nam quốc sơn hà"': 'Nam quốc sơn hà',
#  'thuộc khu vực Trung Âu': 'Trung Âu',
#  'Quốc hội': 'Quốc hội Việt Nam',
#  'Võ đường Ngọc Hòa': 'Võ đường Ngọc Hòa',
#  'Oslo': 'Oslo',
#  '23 làng quan họ cổ': 'Quan họ',
#  'Marie Thérèse Nguyễn Hữu Thị Lan': 'Nam Phương Hoàng hậu',
#  'Shiraz': 'Shiraz',
#  'thành phố Hà Nội': 'Hà Nội',
#  'thể chế cộng hoà đại nghị': 'Cộng hòa đại nghị',
#  'thuộc địa phận huyện Lạc Dương': 'Lạc Dương (huyện)',
#  'Kon Klor': 'Cầu treo Kon Klor',
#  'Đồ Bàn': 'Đồ Bàn',
#  'thành phố Vũng Tàu': 'Vũng Tàu',
#  'thời Thánh Tông': 'Lý Thánh Tông',
#  'Thomas Edison': 'Thomas Edison',
#  'từ ngôn ngữ Hy Lạp': 'Tiếng Hy Lạp',
#  'Nguyễn Văn Siêu': 'Nguyễn Văn Siêu',
#  'Ba Lan': 'Ba Lan',
#  'Ptolemaios XIII': 'Ptolemaios XIII Theos Philopator',
#  'tỉnh Minh Hải': 'Minh Hải (tỉnh)',
#  'Waterloo': 'Trận Waterloo',
#  'Qatar': 'Qatar',
#  'Lê Đức Thọ': 'Lê Đức Thọ',
#  'Nam Phương': 'Nam Phương Hoàng hậu',
#  'Seoul': 'Seoul',
#  'người làng Báo Tháp xã Đông Cứu ( nay thuộc huyện Gia Bình tỉnh Bắc Ninh )': 'Bắc Ninh',
#  'ở São Pedro , Funchal': 'São Paulo',
#  'Lý Thái Tổ': 'Lý Thái Tổ',
#  'Brasília': 'Brasília',
#  'Hang Sơn Đoòng': 'Hang Sơn Đoòng',
#  'Đà Lạt': 'Đà Lạt',
#  'xã Đặng Lễ , huyện Ân Thi , tỉnh Hưng Yên .': 'Hưng Yên',
#  'ở vùng sừng châu Phi': 'Sừng châu Phi',
#  'nằm giữa lòng thủ đô Hà Nội .': 'Hà Nội',
#  'Washington , D.C': 'Washington, D.C.',
#  'phía đông': 'Hướng Đông',
#  'thành phố Hạ Long': 'Hạ Long',
#  'Lý Công Uẩn': 'Lý Thái Tổ',
#  'Nguyễn Việt Hương': 'Việt Hương',
#  'Khối Liên hiệp Anh': 'Vương quốc Liên hiệp Anh và Bắc Ireland',
#  'Jane': 'Jane Seymour',
#  'Priscus': 'Priscus',
#  'nhà tâm lý học Abraham Maslow': 'Abraham Maslow',
#  'Eiichiro Oda': 'Oda Eiichiro',
#  'Lương Định Của': 'Lương Định Của',
#  'Hồ Hán Thương': 'Hồ Hán Thương',
#  'Đông Bắc Á': 'Đông Bắc Á',
#  'thành phố Jaipur': 'Jaipur',
#  'hướng Nam': 'Hướng Nam',
#  'Núi Dài ': 'An Giang',
#  'Phía đông là eo biển Kattegat': 'Kattegat',
#  'Lê Hoàn': 'Lê Đại Hành',
#  'giải thưởng Sao Khuê ': 'Giải thưởng Sao Khuê',
#  'châu Âu': 'Châu Âu',
#  'Tiếng Sotho , cũng được gọi là Sesotho , Nam Sotho , hay Nam " Sesotho': 'Tiếng Sotho',
#  'Chiêu Thánh công chúa': 'Lý Chiêu Hoàng',
#  'Nguyễn Bỉnh Khiêm': 'Nguyễn Bỉnh Khiêm',
#  'đảo Rhodes': 'Rhodes',
#  'giáp với Đại Tây Dương': 'Đại Tây Dương',
#  'đông y': 'Đông y',
#  'Tác phẩm " Chí Phèo "': 'Chí Phèo',
#  'biển Địa Trung Hải': 'Địa Trung Hải',
#  'Cái Răng': 'Cái Răng',
#  'Bắc Ninh': 'Bắc Ninh',
#  'Thomas A. Edison': 'Thomas Edison',
#  'Bình Định': 'Bình Định',
#  'Phú Quốc': 'Phú Quốc',
#  'đồi núi': 'Núi',
#  'Thịt dê': 'Thịt dê',
#  'nằm trên cánh cung Đông Triều ôm gọn vùng Đông Bắc Việt Nam , sườn Đông chủ yếu thuộc tỉnh Quảng Ninh , sườn Tây thuộc tỉnh Bắc Giang .': 'Cánh cung Đông Triều',
#  'đảo Réunion': 'Réunion',
#  'Đặng Thai Mai': 'Đặng Thai Mai',
#  'Thanh Hoá ': 'Thanh Hóa',
#  'Trận Toulon hay Cuộc vây hãm Toulon': 'Cuộc vây hãm Toulon',
#  'Bạch Hổ': 'Mỏ dầu Bạch Hổ',
#  'tiếng Sumer': 'Tiếng Sumer',
#  'nhà Nguyễn thời vua Bảo Đại': 'Nhà Nguyễn',
#  'Đền Ngọc Sơn': 'Đền Ngọc Sơn',
#  'sông Tiền Đường': 'Sông Tiền Đường',
#  'Trịnh Bồng': 'Trịnh Bồng',
#  'vua Hùng thứ XVII': 'Hùng Vương thứ XVII',
#  'Funchal': 'Funchal',
#  'cấp xã': 'Xã',
#  'Ngọ Môn': 'Ngọ Môn (Hoàng thành Huế)',
#  'ở số 5 đại lộ Anatole France , Quận 7 , Paris': 'Paris',
#  'Thích Ca Mâu Ni ( " Shakyamuni " )': 'Thích-ca Mâu-ni',
#  'Papua New Guinea': 'Papua New Guinea',
#  'quê Lệ Thủy, Quảng Bình': 'Lệ Thủy',
#  'Rồng Việt Nam': 'Rồng Việt Nam',
#  'thành phố Vị Thanh': 'Vị Thanh',
#  'thị xã Bắc Giang': 'Bắc Giang (thành phố)',
#  'Yersin': 'Alexandre Yersin',
#  'Mexico': 'México',
#  'Apia': 'Apia',
#  'Trương Minh Nhật Quang': 'Trương Minh Nhật Quang',
#  'triều Nguyễn': 'Nhà Nguyễn',
#  'Philippos II': 'Philippos II của Macedonia',
#  'thành phố Manila': 'Manila',
#  'Thiên Ấn Niêm Hà': 'Núi Thiên Ấn',
#  'Nguyễn Kim': 'Nguyễn Kim',
#  'La Quán Trung': 'La Quán Trung',
#  'Mendel': 'Gregor Mendel',
#  'Trần Khánh Dư': 'Trần Khánh Dư',
#  'ở phường Đội Cấn , quận Ba Đình , thành phố Hà Nội': 'Hà Nội',
#  'thành phố Đồng Hới': 'Đồng Hới',
#  'Liên Hiệp Anh': 'Vương quốc Liên hiệp Anh và Bắc Ireland',
#  'sông Thu Bồn': 'Sông Thu Bồn',
#  'Nam Mỹ ': 'Nam Mỹ',
#  'Trịnh Huệ': 'Trịnh Tuệ',
#  'tỉnh Tây Ninh': 'Tây Ninh',
#  'Hoa Kì': 'Hoa Kỳ',
#  'Louis Braille': 'Louis Braille',
#  'Thành Thái': 'Thành Thái',
#  'Chùa Yên Phú': 'Chùa Yên Phú',
#  'bản Tuyên ngôn Độc lập Hoa Kỳ': 'Tuyên ngôn độc lập Hoa Kỳ',
#  'Lima': 'Lima',
#  'Giải Nobel Hoà bình': 'Giải Nobel Hòa bình',
#  'Khu dự trữ sinh quyển ven biển và biển đảo Kiên Giang': 'Khu dự trữ sinh quyển ven biển và biển đảo Kiên Giang',
#  'Tashkent': 'Tashkent',
#  'Ngô Thừa Ân': 'Ngô Thừa Ân',
#  'tỉnh Đồng Tháp': 'Đồng Tháp',
#  'Hàn Mặc Tử': 'Hàn Mặc Tử',
#  'Vương triều thứ ba': 'Vương triều thứ Ba của Ai Cập',
#  'Võ Văn Hoan': 'Võ Văn Hoan',
#  'quận Cầu Giấy': 'Cầu Giấy',
#  'Valentina Tereshkova': 'Valentina Vladimirovna Tereshkova',
#  'chiến tranh Punic lần III': 'Chiến tranh Punic',
#  'đồng yuan Trung Quốc': 'Yuan Trung Quốc',
#  'Thi Đình': 'Thi Đình',
#  'Sơn La [Mương La]': 'Sơn La',
#  'Cù lao Chàm': 'Cù Lao Chàm',
#  'thị trấn Đông Anh': 'Đông Anh (thị trấn)',
#  'tại Núi Nam giới huyện Thạch Hà , tỉnh Hà Tĩnh': 'Hà Tĩnh',
#  'Từ Dụ Hoàng thái hậu': 'Từ Dụ',
#  'Atacama': 'Hoang mạc Atacama',
#  'Liễu Thăng': 'Liễu Thăng',
#  'thời Lý Thái Tổ': 'Lý Thái Tổ',
#  'hồ Trị An': 'Hồ Trị An',
#  'huyện Nghi Xuân': 'Nghi Xuân',
#  'sông Sài Gòn': 'Sông Sài Gòn',
#  'Quận 3': 'Quận 3',
#  'Buzz Aldrin': 'Buzz Aldrin',
#  'Pamplona': 'Pamplona',
#  'Lào': 'Lào',
#  'Kinshasa ': 'Kinshasa',
#  'Đan Mạch': 'Đan Mạch',
#  'Bình Định Vương Lê Lợi': 'Lê Thái Tổ',
#  'Bãi biển Cửa Lò': 'Bãi biển Cửa Lò',
#  'Trần Anh Tông': 'Trần Anh Tông',
#  'Ngân hàng TMCP Ngoại thương Việt Nam tên viết tắt : " Vietcombank "': 'Ngân hàng thương mại cổ phần Ngoại thương Việt Nam',
#  ' tỉnh Thanh Hoá': 'Thanh Hóa',
#  'Hồ Superior': 'Hồ Thượng',
#  'huyện Châu Thành': 'Châu Thành',
#  'Trujillo ': 'Trujillo',
#  'trăn hoàng gia': 'Trăn hoàng gia',
#  'thời Lý': 'Nhà Lý',
#  'Nga Sơn': 'Nga Sơn',
#  'Lê Văn Thiêm': 'Lê Văn Thiêm',
#  'Edinburgh': 'Edinburgh',
#  'nằm ngay giữa trung tâm thành phố Bắc Kinh': 'Bắc Kinh',
#  'Trần Phú': 'Trần Phú',
#  'lực lượng bộ binh': 'Bộ binh',
#  'Sông Hằng': 'Sông Hằng',
#  'Neil Alden Armstrong': 'Neil Armstrong',
#  'JustaTee hay JayTee': 'JustaTee',
#  'Leonardo da Vinci': 'Leonardo da Vinci',
#  'sống thiếu ánh sáng liên quan gây giảm serotonin': 'Serotonin',
#  'Nguyễn Văn Duệ': 'Nguyễn Văn Duệ',
#  'địa chấn kế Benioff': 'Địa chấn kế',
#  'Benjamin Franklin': 'Benjamin Franklin',
#  'Zing Music Awards': 'Zing Music Awards',
#  'Lý Thánh Tông': 'Lý Thánh Tông',
#  'quả sung': 'Sung',
#  'Hoàng Xuân Vinh': 'Hoàng Xuân Vinh',
#  'Halldór Laxness': 'Halldór Laxness',
#  'Fernão de Magalhães': 'Fernão de Magalhães',
#  'Angkor Wat': 'Angkor Wat',
#  'sông Đồng Nai': 'Sông Đồng Nai',
#  'vịnh Thái Lan ở phía nam': 'Vịnh Thái Lan',
#  'Washington , D.C.': 'Washington, D.C.',
#  'Cao Tông Vương hoàng hậu': 'Vương hoàng hậu (Đường Cao Tông)',
#  'Sahara': 'Sa mạc Sahara',
#  'Sundarban': 'Sundarban',
#  'huyện Bình Xuyên ( Vĩnh Phúc ) .': 'Bình Xuyên',
#  'Lào Cai ': 'Lào Cai',
#  'TP.HCM': 'Thành phố Hồ Chí Minh',
#  'Liên Xô sản xuất': 'Liên Xô',
#  'nhà văn Nguyên Ngọc': 'Nguyên Ngọc',
#  'Randi Jayne Zuckerberg': 'Randi Zuckerberg',
#  'quê ở làng Cổ Trai, huyện Nghi Dương (Hải Dương)': 'Mạc Đăng Dung',
#  'Sundar Pichai': 'Sundar Pichai',
#  'Quảng Ninh': 'Quảng Ninh',
#  'Mauser Kar98k của Đức': 'Karabiner 98k',
#  'Titano': 'Núi Titano',
#  'Cầu Văn Lang': 'Cầu Văn Lang',
#  'Đại Việt': 'Đại Việt',
#  'thủ đô Wellington': 'Wellington',
#  'tỉnh Phú Thọ': 'Phú Thọ',
#  'John J. Loud': 'John J. Loud',
#  'BBK Electronics': 'BBK Electronics',
#  'Thái Bình': 'Thái Bình',
#  'nhà văn Thi Nại Am': 'Thi Nại Am',
#  'Bánh xèo tôm nhảy': 'Bánh xèo tôm nhảy',
#  'Ngọn hải đăng Kê Gà': 'Hải đăng Kê Gà',
#  'Lý Quốc Sư': 'Lý Quốc Sư',
#  'Biển Đỏ': 'Biển Đỏ',
#  'Nguyễn Minh Kha': 'Nguyễn Minh Kha',
#  'Bùi Văn Sơn': 'Bùi Văn Sơn',
#  'vịnh Bahrain': 'Bahrain',
#  'Nam Á': 'Nam Á',
#  'Phan Bội Châu': 'Phan Bội Châu',
#  'nhà Nguyên': 'Nhà Nguyên',
#  'tỉnh Hậu Giang': 'Hậu Giang',
#  ...}

# %%
class QAExtraction(nn.Module):
  def __init__(self, model_name, tokenizer_name, entity_dict, model_checkpoint=None, threshold=0.1, device='cuda'):
    super(QAExtraction, self).__init__()

    model = AutoModelForQuestionAnswering.from_pretrained(model_name, use_auth_token=AUTH_TOKEN).half()

    if model_checkpoint != None:
      model.load_state_dict(torch.load(model_checkpoint))

    self.nlp = pipeline('question-answering', model=model,
                           tokenizer=tokenizer_name, device=0)

    self.threshold = threshold
    self.device = device
    # self.nlp.to(device)
    self.entity_dict = entity_dict

  def forward(self, question, texts, ranking_scores=None):
    if ranking_scores is None:
      ranking_scores = np.ones((len(texts),))

    curr_answers = []
    curr_scores = []
    best_score = 0

    for text, score in zip(texts, ranking_scores):
      QA_input = {
          'question': question,
          'context': text
          }
      res = self.nlp(QA_input)

      # print(res)

      if res['score'] > self.threshold:
        curr_answers.append(res['answer'])
        curr_scores.append(res['score'])

      res["score"] = res["score"] * score
      if res['score'] > best_score:
        answer = res['answer']
        best_score = res['score']

    # chịu
    if len(curr_answers) == 0:
      return None

    curr_answers = [post_process_answer(x, self.entity_dict) for x in curr_answers]
    answer = post_process_answer(answer, self.entity_dict)
    new_best_answer = post_process_answer(find_best_cluster(curr_answers, answer), self.entity_dict)
    return new_best_answer

# %%
qa_model = QAExtraction(MRC_TOKENIZER, MRC_TOKENIZER, entity_dict)

# %%
all_scores = []
all_texts = []
question = rank_wiki.iloc[0]['question']
for idx, row in rank_wiki.iterrows():
  all_texts.append(row['context'])
  all_scores.append(row['bm25_score'] * row['bert_score'])

print(all_texts)
print(all_scores)
print(question)
# Out:
# ['100 ngày đầu nhiệm_kỳ tổng_thống của donald_trump 100 ngày đầu nhiệm_kỳ tổng_thống donald trump bắt_đầu với lễ nhậm_chức của ông làm tổng_thống thứ 45 của hoa kỳ vào trưa ngày 20 tháng 1 năm 2017 phó_tổng_thống hoa kỳ lần thứ 48 mike pence nhậm_chức cùng ngày_ngày thứ 100 nhiệm_kỳ tổng_thống của ông donald trump là 29 tháng 4 năm 2017 100 ngày đầu_tiên trong nhiệm_kỳ của một tổng_thống có ý_nghĩa tượng_trưng trong chính_quyền franklin d roosevelt và giai_đoạn này được coi là một điểm mốc để đo_lường sự thành_công đầu_tiên của một tổng_thống khác với các tổng_thống trước trump thường tuyên_bố phê_phán qua twitter gây nhiều tranh_luận trong giới truyền_thông cũng như trong quần_chúng tuần 1 ngày 1 bài diễn_văn trong bài diễn_văn nhậm_chức ngắn_gọn của mình trump vẽ ra một bức tranh ảm_đạm về tình_trạng của đất_nước đặc_biệt là trong tình_hình kinh_tế và việc giới quyền_lực chính_trị ở thủ_đô làm_giàu trên sương máu của người dân điều này sẽ thay_đổi nhân_dân một lần nữa trở_thành người cai_trị đất_nước này khoảnh_khắc này là của bạn nó thuộc về bạn ông nói vậy với quần_chúng ngoài ra trump hứa sẽ mang lại công ăn việc_làm trong nước và hoàn_toàn quét sạch chủ_nghĩa', 'mặc cho các cáo_buộc và hàng_loạt các cuộc biểu_tình phản_đối vào ngày 20 tháng 1 năm 2017 donald trump nhậm_chức trở_thành tổng_thống thứ 45 của hoa kỳ vào ngày 20 tháng 1 năm 2020 ca nhiễm covid19 đầu_tiên ở hoa kỳ đã được xác_nhận tính đến ngày 7 tháng 3 năm 2021 hoa kỳ có gần 29 triệu ca nhiễm covid19 và hơn 520000 ca tử_vong cho đến nay hoa kỳ là quốc_gia có nhiều người nhiễm covid19 được xác_nhận nhất kể từ ngày 11 tháng 4 năm 2020 cuộc bầu_cử tổng_thống vào cuối năm 2020 khiến donald_trump thất_cử và ứng_viên đảng dân_chủ joe biden đã chiến_thắng những người ủng_hộ donald trump cho rằng cuộc bầu_cử đã xảy ra gian_lận họ tiến_hành bạo_loạn tại điện capitol hoa kỳ 2021 lần đầu_tiên kể từ năm 1814 tòa nhà quốc_hội mỹ bị tấn_công và cướp phá địa_lý hoa kỳ là quốc_gia có tổng_diện_tích lớn thứ ba hoặc thứ tư trên thế_giới trước hoặc sau trung quốc tùy theo hai lãnh_thổ mà ấn độ và trung quốc đang tranh_chấp có được tính vào lãnh_thổ trung_quốc hay không nếu chỉ tính về phần mặt_đất thì hoa kỳ lớn hạng ba sau nga và trung quốc nhưng đứng ngay trước canada canada lớn hơn hoa kỳ về tổng_diện_tích nhưng phần_lớn lãnh_thổ', 'nội_các donald trump là nội_các tổng_thống donald trump trump nhậm_chức tổng_thống ngày 2012017 và theo điều_khoản bổ_nhiệm của hiến_pháp hoa kỳ tổng_thống đề_cử thành_viên trong nội_các để thượng_viện hoa kỳ phê_chuẩn trước khi phê_chuẩn và trước phiên điều_trần quốc_hội thành_viên cao_cấp đứng đầu_cơ_quan trong nội_các thực_hiện với chức_vụ là quyền nội_các này như một phần chuyển_giao quyền_lực sau cuộc bầu_cử tổng_thống hoa kỳ năm 2016 dữ_liệu này ghi lại thông_tin xác_nhận các ứng_viên được bổ_nhiệm hoặc không trong nội_các do tổng_thống chỉ_định chức_vụ được sắp_xếp theo thứ tự bổ_nhiệm trong nội_các cũng được sử_dụng là thứ tự kế_vị tổng_thống hoa_kỳ thành_viên hiện_tại tất_cả các thành_viên nội_các hoa kỳ sau khi được tổng_thống bổ_nhiệm trước khi nhậm_chức bắt_buộc phải được thượng_viện hoa kỳ tư_vấn và chấp_thuận chức_vụ phó_tổng_thống đặc_biệt hơn theo hiến_pháp chức_vụ này phải được thông_qua bởi bầu_cử mặc_dù một_số thành_viên thuộc bậc nội_các không nội_các trong văn_phòng điều_hành của phủ tổng_thống hoa kỳ như chánh văn_phòng nhà trắng cố_vấn an_ninh quốc_gia và thư_ký báo_chí nhà trắng không phải các chức_vụ lập_hiến nên hầu_hết', 'donald_trump donald john trump sinh ngày 14 tháng 6 năm 1946 là một tỷ_phú doanh_nhân người mỹ và là tổng_thống thứ 45 của hoa kỳ từ 2017 đến năm 2021 trump sinh ra và lớn lên ở queens một quận của thành_phố new york theo học đại_học fordham trong hai năm và nhận bằng cử_nhân kinh_tế của trường wharton thuộc đại_học pennsylvania ông trở_thành chủ_tịch công_ty kinh_doanh bất_động_sản của cha mình vào năm 1971 sau đó đổi tên công_ty thành tổ_chức trump và mở_rộng hoạt_động từ queens và brooklyn sang man ...
# [0.24883894834980722, 0.2260611159625351, 0.2205699288473917, 0.21737441240822367, 0.20242787424745562, 0.2004026510446503, 0.18552949539115424, 0.1773413052046448, 0.1538635776212275, 0.15005661885573562, 0.14778216818356507, 0.14068978178133665, 0.13499424794286966, 0.13169433950786708, 0.1205237430770874, 0.10858620531280036, 0.10544433414748311, 0.10535411059650421, 0.09954101492728919, 0.0980621611704528, 0.09758286659789084, 0.08780160992601332, 0.08600860217689185, 0.08384789118237015, 0.0663348763416454, 0.06511501042691707, 0.06433404992284088, 0.05438403750316798, 0.05179959692783354, 0.04463942288269997, 0.04362316951340436, 0.039527370120064916, 0.03505379375772714, 0.03248593065050795, 0.032345301067260794, 0.03233189692324339, 0.031959886677202565, 0.03149917514278293, 0.030769226059691013, 0.028533637316143508, 0.026705759963561292, 0.025597937355113027, 0.024028090104559065, 0.023427656320546865, 0.01877785393381119, 0.0180087144170168, 0.016945420564987504, 0.015822921129498332, 0.015001291739539202, 0.014772357169051765, 0.014593752933999891, 0.014472281855792583, 0.014280328207377877, 0.012692546520985367, 0.01230442492504656, 0.01220948406179112, 0.011833312945563732, 0.011705719857661664, 0.011555531862524893, 0.011454145172655283, 0.01141357847644186, 0.011304874089988318, 0.011117774971629052, 0.011088358423728122, 0.010553910316385862, 0.010088494539775724, 0.01007902541123807, 0.009997354623581646, 0.009700948856444954, 0.009679407170948087, 0.009288513308843224, 0.009211215453658104, 0.00887799633446145, 0.008697896130214686, 0.008584562154978334, 0.008443607521014333, 0.008343969986816106, 0.00810442156843078, 0.008026181621866225, 0.00802188526494902, 0.007650995904973149, 0.007538372466353415, 0.007487291166335342, 0.007462474400768756, 0.007390623234989551, 0.007389563124105543, 0.007388294240158796, 0.007163989861118314, 0.007060164412512406, 0.00674557115148258, 0.006737265845729111, 0.006656689314424394, 0.00662797100519228, 0.006309083411654366, 0.006189789035856126, 0.006024885588834284, 0.006021419442398219, 0.006014836883571862, 0.005828998427824824, 0.005810008490904719]
# donald trump làm tổng_thống hoa kỳ từ thơi điểm nào

# %%
res = qa_model(question, all_texts, all_scores)
# Out:
# {'score': 8.42225801989116e-07, 'start': 166, 'end': 195, 'answer': 'trưa ngày 20 tháng 1 năm 2017'}
# {'score': 3.4517122458055383e-06, 'start': 157, 'end': 181, 'answer': 'ngày 20 tháng 1 năm 2020'}
# {'score': 0.11288753151893616, 'start': 83, 'end': 95, 'answer': 'ngày 2012017'}
# {'score': 0.9999889135360718, 'start': 130, 'end': 150, 'answer': 'từ 2017 đến năm 2021'}
# {'score': 1.2059714435963542e-06, 'start': 225, 'end': 233, 'answer': 'năm 2016'}
# {'score': 0.9923509955406189, 'start': 171, 'end': 219, 'answer': 'trong thời_gian tranh_cử tổng_thống vào năm 2016'}
# {'score': 2.863438623990078e-07, 'start': 49, 'end': 109, 'answer': 'buổi trưa theo giờ est 1700 giờ utc ngày 20 tháng 1 năm 2017'}
# {'score': 1.8905417595999063e-12, 'start': 0, 'end': 8, 'answer': 'nhiệm_kỳ'}
# {'score': 0.9999533891677856, 'start': 814, 'end': 822, 'answer': 'năm 1979'}
# {'score': 0.2710799276828766, 'start': 999, 'end': 1007, 'answer': 'năm 2016'}
# {'score': 2.6608958092477764e-12, 'start': 470, 'end': 490, 'answer': 'vào tháng 9 năm 2018'}
# {'score': 1.573974617308238e-09, 'start': 152, 'end': 176, 'answer': 'ngày 20 tháng 1 năm 2017'}
# {'score': 2.892583381708391e-07, 'start': 850, 'end': 874, 'answer': 'ngày 2 tháng 12 năm 2016'}
# {'score': 1.5857854309200836e-12, 'start': 870, 'end': 885, 'answer': 'hoa kỳ đã đề_cử'}
# {'score': 5.654277046573952e-08, 'start': 47, 'end': 70, 'answer': 'ngày 1 tháng 6 năm 2017'}
# {'score': 2.5003024650693817e-10, 'start': 0, 'end': 4, 'answer': '2017'}
# {'score': 0.9990969300270081, 'start': 178, 'end': 182, 'answer': '2016'}
# {'score': 2.2064293447865424e-10, 'start': 590, 'end': 631, 'answer': 'sau khi giành quyền kiểm_soát thượng_viện'}
# {'score': 4.9131094783660956e-06, 'start': 303, 'end': 319, 'answer': 'ngày 11 12112017'}
# {'score': 0.027347778901457787, 'start': 388, 'end': 412, 'answer': 'ngày 9 tháng 11 năm 2016'}
# {'score': 1.0319512711021162e-07, 'start': 68, 'end': 74, 'answer': 'thứ 45'}
# {'score': 5.811932268784403e-08, 'start': 1196, 'end': 1210, 'answer': 'ngày 6 tháng 1'}
# {'score': 3.06291519924784e-11, 'start': 581, 'end': 596, 'answer': 'dựa trên vị_trí'}
# {'score': 9.777956574844385e-14, 'start': 642, 'end': 645, 'answer': 'năm'}
# {'score': 3.344489962753272e-11, 'start': 877, 'end': 901, 'answer': 'ngày 25 tháng 1 năm 2017'}
# {'score': 5.099696359645023e-11, 'start': 428, 'end': 436, 'answer': 'tối 1111'}
# {'score': 7.652670319657773e-06, 'start': 803, 'end': 811, 'answer': 'năm 2006'}
# {'score': 1.9277838418929605e-06, 'start': 974, 'end': 999, 'answer': 'ngày 12 tháng 12 năm 2017'}
# {'score': 9.453365173994754e-11, 'start': 738, 'end': 773, 'answer': 'từ ngày 10 đến 12 tháng 11 năm 2017'}
# {'score': 3.9796879680586983e-10, 'start': 246, 'end': 263, 'answer': 'tháng 11 năm 2020'}
# {'score': 0.7954341769218445, 'start': 1018, 'end': 1056, 'answer': 'khoảng 42 tháng trước ngày bầu_cử 2020'}
# {'score': 0.03460211679339409, 'start': 744, 'end': 768, 'answer': 'ngày 15 tháng 5 năm 2019'}
# {'score': 4.970451676113152e-13, 'start': 148, 'end': 156, 'answer': 'năm 2015'}
# {'score': 6.170403594296658e-06, 'start': 322, 'end': 331, 'answer': 'nguồn_gốc'}
# {'score': 1.3246386743048788e-06, 'start': 740, 'end': 764, 'answer': 'ngày 24 tháng 1 năm 2017'}
# {'score': 0.005629267077893019, 'start': 298, 'end': 322, 'answer': 'ngày 27 tháng 6 năm 2017'}
# {'score': 0.07640203833580017, 'start': 740, 'end': 765, 'answer': 'năm 2020 bbc thứ 5 ngày 3'}
# {'score': 1.6233709175139666e-05, 'start': 44, 'end': 59, 'answer': 'ngày 29 tháng 5'}
# {'score': 5.2922933396759575e-11, 'start': 97, 'end': 112, 'answer': 'ngày 2 tháng 11'}
# {'score': 1.4025837435927002e-10, 'start': 553, 'end': 569, 'answer': 'tháng 1 năm 2017'}
# {'score': 1.8542549440336842e-11, 'start': 0, 'end': 25, 'answer': 'ngày 31 tháng 12 năm 2019'}
# {'score': 8.17112231743522e-05, 'start': 773, 'end': 789, 'answer': 'tháng 7 năm 1905'}
# {'score': 1.7793013284972403e-08, 'start': 798, 'end': 813, 'answer': 'năm 1985 – 1987'}
# {'score': 4.794956680598261e-07, 'start': 166, 'end': 176, 'answer': '16 tháng 1'}
# {'score': 1.7681605868347106e-06, 'start': 617, 'end': 647, 'answer': 'sinh ngày 31 tháng 12 năm 1977'}
# {'score': 8.833571314426081e-07, 'start': 77, 'end': 83, 'answer': 'thứ 45'}
# {'score': 1.4767940342830244e-11, 'start': 801, 'end': 809, 'answer': 'năm 1999'}
# {'score': 8.035639353920487e-08, 'start': 173, 'end': 189, 'answer': 'tháng 1 năm 2017'}
# {'score': 3.128726661430492e-13, 'start': 1079, 'end': 1114, 'answer': 'cầm_quyền thị_trường chứng_khoán mỹ'}
# {'score': 1.0504266900746018e-10, 'start': 879, 'end': 887, 'answer': 'năm 2004'}
# {'score': 0.9987783432006836, 'start': 500, 'end': 536, 'answer': 'năm 1918 đến năm 1926 công_ty của họ'}
# {'score': 0.6428385376930237, 'start': 1123, 'end': 1131, 'answer': 'năm 1960'}
# {'score': 2.1177527287363773e-08, 'start': 275, 'end': 290, 'answer': 'khoảng năm 1968'}
# {'score': 3.552753794280883e-12, 'start': 55, 'end': 79, 'answer': 'ngày 7 tháng 10 năm 2016'}
# {'score': 1.0838338226903943e-08, 'start': 933, 'end': 949, 'answer': 'tháng 5 năm 2019'}
# {'score': 1.2207712618561573e-10, 'start': 1077, 'end': 1106, 'answer': 'trước khi ông trump nhậm_chức'}
# {'score': 7.858246249270451e-07, 'start': 268, 'end': 292, 'answer': 'ngày 30 tháng 6 năm 2019'}
# {'score': 3.9639445503780735e-08, 'start': 1120, 'end': 1144, 'answer': 'ngày 1 tháng 10 năm 2017'}
# {'score': 1.294153975095469e-07, 'start': 931, 'end': 939, 'answer': 'năm 2016'}
# {'score': 1.811044512578519e-06, 'start': 432, 'end': 448, 'answer': 'từ 2005 tới 2008'}
# {'score': 1.350274669675855e-05, 'start': 1080, 'end': 1104, 'answer': 'ngày 20 tháng 1 năm 2017'}
# {'score': 2.2005782795986306e-07, 'start': 318, 'end': 339, 'answer': 'vào tháng 12 năm 2000'}
# {'score': 6.089960350244561e-13, 'start': 0, 'end': 7, 'answer': 'tháng 4'}
# {'score': 9.678840839910663e-09, 'start': 238, 'end': 261, 'answer': 'ngày 5 tháng 2 năm 2019'}
# {'score': 9.035488091058141e-08, 'start': 208, 'end': 216, 'answer': 'năm 2020'}
# {'score': 1.0302204422885097e-08, 'start': 85, 'end': 101, 'answer': 'tháng 8 năm 2018'}
# {'score': 4.456163302940519e-12, 'start': 677, 'end': 694, 'answer': 'tháng 11 năm 2020'}
# {'score': 2.579377544886796e-10, 'start': 320, 'end': 343, 'answer': 'các buổi tập_hợp cử_tri'}
# {'score': 2.6817786272920197e-12, 'start': 106, 'end': 130, 'answer': 'ngày 25 tháng 1 năm 2018'}
# {'score': 3.370697124194244e-11, 'start': 783, 'end': 799, 'answer': 'ngày 13 tháng 11'}
# {'score': 1.4017061857884983e-06, 'start': 714, 'end': 722, 'answer': 'năm 2012'}
# {'score': 1.0442151483769369e-11, 'start': 155, 'end': 179, 'answer': 'ngày 11 tháng 9 năm 2018'}
# {'score': 7.120911065666702e-12, 'start': 115, 'end': 144, 'answer': 'đôi_khi được gọi là chủ_nghĩa'}
# {'score': 2.3799103132660093e-07, 'start': 869, 'end': 875, 'answer': 'thứ 45'}
# {'score': 5.88179616123341e-10, 'start': 497, 'end': 505, 'answer': 'năm 2017'}
# {'score': 0.9749724268913269, 'start': 619, 'end': 635, 'answer': 'đến đầu năm 2015'}
# {'score': 4.855947241533265e-12, 'start': 891, 'end': 905, 'answer': 'một bước_ngoặt'}
# {'score': 1.897460037980636e-07, 'start': 213, 'end': 221, 'answer': 'năm 2017'}
# {'score': 1.5431527583542604e-11, 'start': 663, 'end': 671, 'answer': 'chủ_tịch'}
# {'score': 4.31605080564168e-08, 'start': 647, 'end': 670, 'answer': 'tháng 1 năm 2021 trở đi'}
# {'score': 1.6886855247477683e-09, 'start': 319, 'end': 335, 'answer': 'từ_chức năm 2009'}
# {'score': 7.289755604711345e-12, 'start': 0, 'end': 41, 'answer': 'một trăm ngày đầu_tiên trong nhiệm_kỳ đầu'}
# {'score': 3.252903317801231e-14, 'start': 31, 'end': 42, 'answer': 'kim và moon'}
# {'score': 3.9299663967540255e-08, 'start': 1014, 'end': 1028, 'answer': 'ngày 3 tháng 7'}
# {'score': 6.835813692873671e-09, 'start': 766, 'end': 774, 'answer': 'năm 2016'}
# {'score': 1.0103241798731233e-08, 'start': 218, 'end': 226, 'answer': 'năm 2016'}
# {'score': 4.9743512136046775e-06, 'start': 1062, 'end': 1075, 'answer': 'ngày 11012021'}
# {'score': 8.230002235265488e-10, 'start': 726, 'end': 742, 'answer': 'tháng 7 năm 2020'}
# {'score': 1.319799955087908e-12, 'start': 91, 'end': 132, 'answer': 'khi tổng_thống donald trump lên cầm_quyền'}
# {'score': 7.319796990756799e-10, 'start': 159, 'end': 192, 'answer': 'ngày vào ngày 22 tháng 3 năm 2018'}
# {'score': 4.1784964377455935e-11, 'start': 20, 'end': 27, 'answer': '1522019'}
# {'score': 2.844297297688314e-10, 'start': 519, 'end': 530, 'answer': 'từ năm 1949'}
# {'score': 1.7905604776657924e-09, 'start': 157, 'end': 165, 'answer': 'năm 2016'}
# {'score': 1.5980471346210834e-07, 'start': 62, 'end': 70, 'answer': 'năm 1988'}
# {'score': 4.5630130229845633e-10, 'start': 684, 'end': 688, 'answer': '2016'}
# {'score': 1.0327601675328563e-13, 'start': 835, 'end': 870, 'answer': 'công_cuộc phát_triển kinh_tế xã_hội'}
# {'score': 4.1223136015844375e-10, 'start': 51, 'end': 59, 'answer': 'năm 2020'}
# {'score': 0.9936370849609375, 'start': 77, 'end': 83, 'answer': 'thứ 45'}
# {'score': 5.470919550720765e-11, 'start': 357, 'end': 378, 'answer': 'nhận quà từ chính_phủ'}
# {'score': 4.819152854551589e-10, 'start': 0, 'end': 33, 'answer': 'giải tin giả anh fake news awards'}

# %%
print(res)
# Out:
# từ 2017 đến năm 2021

# %% [markdown]
# #END
